# %%
#i wanted to pull out the clusteres that are built into the sns clustermap quantitatively using the dendrograms
# but this exmaple: https://itecnote.com/tecnote/python-extracting-clusters-from-seaborn-clustermap/
#has some re-writing back to the beginning so im going to try that here

# %%
import numpy as np
import pandas as pd
import wikifunctions as wf #Brian's stuff

from collections import Counter

from urllib.parse import unquote

import seaborn as sns
import matplotlib.pyplot as plt
import datetime

import pickle

# %%
import os
print(os.getcwd())
# Out:
# /Users/hannahjones/Library/CloudStorage/Dropbox/Laurie Jones/4_CMArabSpring/Analysis4_Heatmaps

# %% [markdown]
# ## English

# %%
path = '/Users/hannahjones/Library/CloudStorage/Dropbox/Laurie Jones/4_CMArabSpring/Analysis2_Historical hyperlink networks'
with open(path + '/02c_outlinkInclusiondf_en.pkl', 'rb') as f:
    en_data = pickle.load(f)

# %%
#this is for broken up heatmaps
#https://seaborn.pydata.org/generated/seaborn.heatmap.html
plt.style.use("seaborn")

# fig, ax = plt.subplots(figsize=(10, 5))
# plt.figure(figsize = (13,13))
# heat_map = sns.heatmap(en_data.iloc[800:836], yticklabels = True) #first 100 columns
# plt.title("Outlinks Through Time(801-837)")
# plt.savefig("801_837outlinkHeatmap.png")
# plt.show()

# %%
from scipy.spatial.distance import pdist
from scipy.spatial.distance import squareform

squareform(pdist(en_data.loc[:]))
pairDf_en = 1 - pd.DataFrame( squareform(pdist(en_data.loc[:], metric='cosine')),
    columns = en_data.index,
    index = en_data.index
)

# %%
pairDf_en.head()
# Out:
#                                         15 October 2011 global protests  \
# 15 October 2011 global protests                                  1.0000
# 2000s energy crisis                                              0.0000
# 2004–05 Palestinian local elections                              0.0000
# 2005 Ahvaz unrest                                                0.3669
# 2005 Palestinian presidential election                           0.0000
#
#                                         2000s energy crisis  \
# 15 October 2011 global protests                         0.0
# 2000s energy crisis                                     1.0
# 2004–05 Palestinian local elections                     0.0
# 2005 Ahvaz unrest                                       0.0
# 2005 Palestinian presidential election                  0.0
#
#                                         2004–05 Palestinian local elections  \
# 15 October 2011 global protests                                         0.0
# 2000s energy crisis                                                     0.0
# 2004–05 Palestinian local elections                                     1.0
# 2005 Ahvaz unrest                                                       0.0
# 2005 Palestinian presidential election                                  1.0
#
#                                         2005 Ahvaz unrest  \
# 15 October 2011 global protests                    0.3669
# 2000s energy crisis                                0.0000
# 2004–05 Palestinian local elections                0.0000
# 2005 Ahvaz unrest                                  1.0000
# 2005 Palestinian presidential election             0.0000
#
#                                         2005 Palestinian presidential election  \
# 15 October 2011 global protests                                            0.0
# 2000s energy crisis                                                        0.0
# 2004–05 Palestinian local elections                                        1.0
# 2005 Ahvaz unrest                                                          0.0
# 2005 Palestinian presidential election                                     1.0
#
#                                         2006 Palestinian legislative election  \
# 15 October 2011 global protests                                           0.0
# 2000s energy crisis                                                       0.0
# 2004–05 Palestinian local elections                                       1.0
# 2005 Ahvaz unrest                                                         0.0
# 2005 Palestinian presidential election                                    1.0
#
#                                         2007–2008 world food price crisis  \
# 15 October 2011 global protests                                  0.661143
# 2000s energy crisis                                              0.000000
# 2004–05 Palestinian local elections                              0.164399
# 2005 Ahvaz unrest                                                0.434959
# 2005 Palestinian presidential election                           0.164399
#
#                                         2008 Armenian presidential election  \
# 15 October 2011 global protests                                         0.0
# 2000s energy crisis                                                     0.0
# 2004–05 Palestinian local elections                                     0.0
# 2005 Ahvaz unrest                                                       0.0
# 2005 Palestinian presidential election                                  0.0
#
#                                         2009 Iranian presidential election protests  \
# 15 October 2011 global protests                                            0.930949
# 2000s energy crisis                                                        0.000000
# 2004–05 Palestinian local elections                                        0.129099
# 2005 Ahvaz unrest                                                          0.341565
# 2005 Palestinian presidential election                                     0.129099
#
#                                         2010 Kyrgyz Revolution  ...   YouTube  \
# 15 October 2011 global protests                       0.733799  ...  0.000000
# 2000s energy crisis                                   0.000000  ...  0.103695
# 2004–05 Palestinian local elections                   0.000000  ...  0.000000
# 2005 Ahvaz unrest                                     0.357143  ...  0.000000
# 2005 Palestinian presidential election                0.000000  ...  0.000000
#
#                                            Youth  Youthquake  \
# 15 October 2011 global protests         0.459933         0.0
# 2000s energy crisis                     0.000000         0.0
# 2004–05 Palestinian local elections     0.000000         0.0
# 2005 Ahvaz unrest                       0.000000         0.0
# 2005 Palestinian presidential election  0.000000         0.0
#
#                                         Youthquake (movement)  \
# 15 October 2011 global protests                      0.700067
# 2000s energy crisis                                  0.000000
# 2004–05 Palestinian local elections                  0.000000
# 2005 Ahvaz unrest                                    0.460566
# 2005 Palestinian presidential election               0.000000
#
#                                         Yoweri Museveni   Zaydism  \
# 15 October 2011 global protests                     0.0  0.000000
# 2000s energy crisis                                 0.0  0.109764
# 2004–05 Palestinian local elections                 1.0  0.000000
# 2005 Ahvaz unrest                                   0.0  0.000000
# 2005 Palestinian presidential election              1.0  0.000000
#
#                                         Zeynep Tufekci  Zimbabwe  \
# 15 October 2011 global protests               0.000000       0.0
# 2000s energy crisis                           0.112509       0.0
# 2004–05 Palestinian local elections           0.000000       1.0
# 2005 Ahvaz unrest                             0.000000       0.0
# 2005 Palestinian presidential election        0.000000       1.0
#
#                                         Zine El Abidine Ben Ali   Zouérat
# 15 October 2011 global protests                        0.586831  0.423659
# 2000s energy crisis                                    0.081379  0.000000
# 2004–05 Palestinian local elections                    0.081379  0.000000
# 2005 Ahvaz unrest                                      0.215308  0.577350
# 2005 Palestinian presidential election                 0.081379  0.000000
#
# [5 rows x 837 columns]

# %%
plt.figure(figsize=(13,13))
heat_map = sns.heatmap(pairDf_en,)
plt.title('Outlinks with Spatial Distance, total')
plt.savefig("03out_spatialOutlink_tot_ar.png")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#https://seaborn.pydata.org/generated/seaborn.clustermap.html

clusterPlt = sns.clustermap(pairDf_en)
clusterPlt.fig.suptitle("Outlinks with Spatial Distance, cluster")
# clusterPlt.savefig("03out_spatialOutlink_cluster.png")

clusterPlt

# %% [markdown]
# # Trial 1

# %%
#the new cluster map
#https://itecnote.com/tecnote/python-extracting-clusters-from-seaborn-clustermap/

from scipy.cluster import hierarchy


network_pal = sns.cubehelix_palette(len(pairDf_en),
                                    light=.9, dark=.1, reverse=True,
                                    start=1, rot=-2)
network_lut = dict(zip(map(str, pairDf_en), network_pal))

#networks = pairDf_en.columns.get_level_values("network")
network_colors = pd.Series(pairDf_en.all()).map(network_lut)

cmap = sns.diverging_palette(h_neg=210, h_pos=350, s=90, l=30, as_cmap=True)


#this is the main thing i want to attain ############################
correlations = pairDf_en.corr()
correlations_array = np.asarray(pairDf_en.corr())

row_linkage = hierarchy.linkage(
    pdist(correlations_array), method='average')

col_linkage = hierarchy.linkage(
    pdist(correlations_array.T), method='average')
########################################################################

g = sns.clustermap(correlations, row_linkage=row_linkage, col_linkage=col_linkage, row_colors=network_colors, method="average",
               col_colors=network_colors, figsize=(13, 13), cmap=cmap)

g.ax_row_dendrogram.remove()

# %%
correlations_array
# Out:
# array([[ 1.        , -0.10214482, -0.33960575, ..., -0.33960575,
#          0.62027283,  0.55106144],
#        [-0.10214482,  1.        , -0.14342705, ..., -0.14342705,
#          0.11572493, -0.24104478],
#        [-0.33960575, -0.14342705,  1.        , ...,  1.        ,
#         -0.41347549, -0.23795668],
#        ...,
#        [-0.33960575, -0.14342705,  1.        , ...,  1.        ,
#         -0.41347549, -0.23795668],
#        [ 0.62027283,  0.11572493, -0.41347549, ..., -0.41347549,
#          1.        ,  0.09755815],
#        [ 0.55106144, -0.24104478, -0.23795668, ..., -0.23795668,
#          0.09755815,  1.        ]])

# %%
#https://stackoverflow.com/questions/67277384/i-dont-understand-the-detailed-behavior-of-the-threshold-working-in-fcluster-m
#going to have to still qualitatively look at these but this helps pull out wha tit identified

from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

Z = linkage(pairDf_en, method='complete')

# calculate full dendrogram
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

#plt.axhline(9, color='k', ls='--'); #9 is a threshold

# %%
# fcluster(row_linkage, 12, criterion='distance')

# %%
#this shows a truncated dendrogram, which only shows the last p=12 out of our 149 merges.



plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('sample index or (cluster size)')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=30,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %% [markdown]
# # Second Try

# %%
#https://nbviewer.org/gist/vals/150ec97a5b7db9c82ee9

# %%
from collections import defaultdict
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, set_link_color_palette
from fastcluster import linkage
import seaborn as sns
from matplotlib.colors import rgb2hex, colorConverter

# %%
#set some prettier non-default colors.

sns.set_palette('Set1', 10, 0.65)
palette = sns.color_palette()
#set_link_color_palette(map(rgb2hex, palette))
sns.set_style('white')

# %%
#from scipy.spatial.distance import pdist
# from scipy.spatial.distance import squareform

# squareform(pdist(en_data.loc[:]))
# pairDf_en = 1 - pd.DataFrame( squareform(pdist(en_data.loc[:], metric='cosine')),
#     columns = en_data.index,
#     index = en_data.index
# )

# %%
#"linkage” function andits siblings in the scipy.cluster.hierarchy module.

#link = linkage(df, metric='correlation', method='ward')

#description of fastcluster: https://github.com/cran/fastcluster/blob/master/src/python/fastcluster.py
# i think that r'''Hierarchical, agglomerative clustering on a dissimilarity matrix or on
# Euclidean data.
# Apart from the argument 'preserve_input', the method has the same input
# parameters and output format as the functions of the same name in the
# module scipy.cluster.hierarchy.

#that is: A condensed distance matrix. A condensed distance matrix is a flat array 
# containing the upper triangular of the distance matrix. This is the form that pdist returns.

# %%
#method - https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.linkage.html
#https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.distance.pdist.html

#link = linkage(pairDf_en, metric='cosine', method='single')
link = linkage(en_data.loc[:], metric='cosine', method='average')

# %%
plt.figsize(8, 5)
den = dendrogram(link, labels=pairDf_en.index)#, abv_threshold_color='#AAAAAA')
plt.xticks(rotation=90)
no_spine = {'left': True, 'bottom': True, 'right': True, 'top': True}
sns.despine(**no_spine);

plt.tight_layout()
#plt.savefig('tree1.png');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plt.figsize(8, 5)
#       2 den = dendrogram(link, labels=pairDf_en.index)#, abv_threshold_color='#AAAAAA')
#       3 plt.xticks(rotation=90)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'figsize'

# %%
# The tree is represented as a collection of ∏ shaped components.
# The three items named 'color_list', 'dcoord', 'icoord' indexes these ∏'s

# The coordinates go from left to right. So for the red ∏, the 'legs' are located at 15 and 25, 
# while the grey one has legs at 5 and 20.

# The apperant pattern is that legs positioned at leaves will end with 4 or 5. The reason is to nicely 
# place the leg at the middle of the corresponding leaf index value. This also implies the actual 
# list indices of the leaf are multiplied by 10.


den
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 12
#       1 # The tree is represented as a collection of ∏ shaped components.
#       2 # The three items named 'color_list', 'dcoord', 'icoord' indexes these ∏'s
#       3
#    (...)
#       8 # place the leg at the middle of the corresponding leaf index value. This also implies the actual
#       9 # list indices of the leaf are multiplied by 10.
# ---> 12 den
#
# NameError: name 'den' is not defined

# %%
# We first subtract 5 from each colors icoord, then divide by 10. 
# If the resulting number is close to the closest integer, we consider 
# this to be an index for a leaf. If the resulting number is not close 
# to an integer index, it means the colored tree we got it from is from non-leaf parts of the trees.

# For each leaf, we add it to a list per color in a dictionary.
cluster_idxs = defaultdict(list)
for c, pi in zip(den['color_list'], den['icoord']):
    for leg in pi[1:3]:
        i = (leg - 5.0) / 10.0
        if abs(i - int(i)) < 1e-5:
            cluster_idxs[c].append(int(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 8
#       1 # We first subtract 5 from each colors icoord, then divide by 10.
#       2 # If the resulting number is close to the closest integer, we consider
#       3 # this to be an index for a leaf. If the resulting number is not close
#       4 # to an integer index, it means the colored tree we got it from is from non-leaf parts of the trees.
#       5
#       6 # For each leaf, we add it to a list per color in a dictionary.
#       7 cluster_idxs = defaultdict(list)
# ----> 8 for c, pi in zip(den['color_list'], den['icoord']):
#       9     for leg in pi[1:3]:
#      10         i = (leg - 5.0) / 10.0
#
# NameError: name 'den' is not defined

# %%
cluster_idxs
# Out:
# defaultdict(list, {})

# %%
# Next we need to grab the labels of the leaves given the indexes. 
# But before we do that, since it's difficult to keep track of what color e.g. '
# #c13d3f' is, we make make an IPython notebook compatible HTML representation of the 
# dictionary holding the information. Objects of this class will behave just like dictionaries, 
# except for representing them as a HTML table.

#(Note that the representation uses colerConverter from matplotlib, so it supports 
#any matplotlib supported color representation, not only hex color strings.)

class Clusters(dict):
    def _repr_html_(self):
        html = '<table style="border: 0;">'
        for c in self:
            hx = rgb2hex(colorConverter.to_rgb(c))
            html += '<tr style="border: 0;">' \
            '<td style="background-color: {0}; ' \
                       'border: 0;">' \
            '<code style="background-color: {0};">'.format(hx)
            html += c + '</code></td>'
            html += '<td style="border: 0"><code>' 
            html += repr(self[c]) + '</code>'
            html += '</td></tr>'
        
        html += '</table>'
        
        return html

# %%
#go through the list of indices and fetch labels.

cluster_classes = Clusters()
for c, l in cluster_idxs.items():
    i_l = [den['ivl'][i] for i in l]
    cluster_classes[c] = i_l

# %%
cluster_classes
# Out:
# {'C1': ['Adam Roberts (scholar)',
#   'Andrew Reynolds (political scientist)',
#   'Armed Forces & Society',
#   'BBC',
#   'CNN',
#   'Carnegie Endowment for International Peace',
#   'Council on Foreign Relations',
#   'Der Spiegel',
#   'Digital object identifier',
#   'Financial Times',
#   'Foreign Affairs',
#   'Hürriyet Daily News',
#   'ISBN',
#   'Interface: A Journal for and About Social Movements',
#   'International Standard Serial Number',
#   'Jack Goldstone',
#   'Jadaliyya',
#   'Peer review',
#   'Pluto Press',
#   'Qantara.de',
#   'Research Papers in Economics',
#   'Robert Pelletreau',
#   'Robert Struble Jr.',
#   'Ruaridh Arrow',
#   'Semantic Scholar',
#   'Social Science Research Network',
#   'The Guardian',
#   'The National (Abu Dhabi)',
#   'The New York Times',
#   'Timothy Garton Ash',
#   'Reuters',
#   'Douma, Syria',
#   'Secularism',
#   'Tunis',
#   'Civil disobedience',
#   'Defection',
#   'Election',
#   'Employment',
#   'Internet activism',
#   'Kleptocracy',
#   'Protest camp',
#   'Sectarianism',
#   'Sit-in',
#   'Strike action',
#   'Urban warfare',
#   '2000s energy crisis',
#   'Arab Spring concurrent incidents',
#   'Demographic trap',
#   'Economic freedom',
#   'Mutiny',
#   'Silent protest',
#   'Modernization theory',
#   'Relative deprivation',
#   'Fouad Hussein',
#   'Palestinian territories',
#   'Somalia',
#   "Coup d'état",
#   'Islah',
#   'Second Libyan Civil War',
#   'Baba Amr',
#   'Interventionism (politics)',
#   'Kurdish languages',
#   'Middle East',
#   'Palestinian National Authority',
#   'Standard of living',
#   'Abdelaziz Bouteflika',
#   'Muslim Brotherhood',
#   'State of Palestine',
#   'Human Development Index',
#   'Oman',
#   'Hezbollah',
#   'Lebanon',
#   'Mauritania',
#   'Bahrain',
#   'Facebook',
#   'Khuzestan province',
#   'Battle of Misrata',
#   'Omar Suleiman',
#   '2011 Bahraini uprising',
#   '2011 Iraqi protests',
#   '2011 Omani protests',
#   '2011–2012 Mauritanian protests',
#   '2011–2012 Moroccan protests',
#   '2011–2012 Saudi Arabian protests',
#   '2011–2013 Sudanese protests',
#   'Abdullah II of Jordan',
#   'Civil resistance',
#   'Damascus',
#   'Elections in Yemen',
#   "General People's Congress (Yemen)",
#   'Human rights',
#   'Human rights in Bahrain',
#   'Iraq',
#   'King of Bahrain',
#   'Kuwaiti protests (2011–2012)',
#   'Laayoune',
#   'Manama',
#   'Muammar Gaddafi',
#   'National Transitional Council',
#   'Nobel Peace Prize',
#   'Nouri al-Maliki',
#   'Pearl Roundabout',
#   'Political corruption',
#   'Political freedom',
#   'Revolutionary wave',
#   'Riyadh',
#   'Sidi Bouzid',
#   'State of emergency',
#   'Supreme Council of the Armed Forces',
#   'Xinhua News Agency',
#   'Benghazi',
#   '2010–2012 Algerian protests',
#   '2011 Egyptian revolution',
#   'Tunisian Revolution',
#   '2011–2012 Jordanian protests',
#   '2012 Egyptian presidential election',
#   'Al-Hasakah',
#   'Ali Abdullah Saleh',
#   'Arab states of the Persian Gulf',
#   'Constitution of Yemen',
#   'Hosni Mubarak',
#   'Human rights in Yemen',
#   'Mohamed Bouazizi',
#   'Mohamed ElBaradei',
#   'Omar al-Bashir',
#   'Parliament of Egypt',
#   'Sanaa',
#   'Saudi Arabia',
#   'Self-immolation',
#   'Social media',
#   'Sudan',
#   'Tawakkol Karman',
#   'Yemeni Revolution',
#   'Zine El Abidine Ben Ali',
#   'Jordan',
#   'Algeria',
#   'Egypt',
#   'Syria',
#   'Tahrir Square',
#   'Bashar al-Assad',
#   'Tripoli',
#   'United States diplomatic cables leak',
#   'Abdrabbuh Mansur Hadi',
#   'Essam Sharaf',
#   'Hashid',
#   'Prime Minister of Egypt',
#   'Gulf of Sidra',
#   'Libyan Desert',
#   '2011 Western Saharan protests',
#   'Hamad bin Isa Al Khalifa',
#   'Ajdabiya',
#   'Battle of Brega–Ajdabiya road',
#   'Brega',
#   'First Gulf of Sidra offensive',
#   'Misrata',
#   'No-fly zone',
#   'Ash-shab yurid isqat an-nizam',
#   '2011 military intervention in Libya',
#   'United Nations Security Council Resolution 1973',
#   '2011 Djiboutian protests',
#   'Aden',
#   'Aleppo',
#   'Beji Caid Essebsi',
#   'Constitution of Egypt',
#   'Daraa',
#   'Deir ez-Zor',
#   'Democratic Constitutional Rally',
#   'Emergency law in Egypt',
#   'Freedom of speech',
#   'Gafsa',
#   'Gdeim Izik protest camp',
#   'Gulf Cooperation Council',
#   'Habitability',
#   'Hama',
#   'Impact of the Arab Spring',
#   'Inflation',
#   'Mohamed Ghannouchi',
#   'Peninsula Shield Force',
#   'President of Tunisia',
#   'Sahrawis',
#   'Suheir Atassi',
#   'Taiz',
#   'Arabs',
#   'Cairo',
#   'Iran',
#   'Nafusa Mountains',
#   'Prague Spring',
#   'President of Egypt',
#   'Saif al-Islam Gaddafi',
#   'Libya',
#   'Tunisia',
#   'North Africa',
#   'Yemen',
#   'Arabic',
#   'Dictatorship',
#   'United States',
#   "2013 Egyptian coup d'état",
#   'Iraq War',
#   'Media activism',
#   '2012–2013 Egyptian protests',
#   'Liberal democracy',
#   'Marc Lynch',
#   'Mali War',
#   'Revolutions of 1848',
#   'Al Jazeera',
#   'BBC News',
#   'Bani Walid',
#   'Battle of Bani Walid',
#   'Battle of Sabha',
#   'Battle of Sirte (2011)',
#   'Battle of Tripoli (2011)',
#   'Sabha, Libya',
#   'Tripolitania',
#   '2011 Nobel Peace Prize',
#   "Arab Socialist Ba'ath Party – Syria Region",
#   'Sirte',
#   'Bab al-Azizia',
#   'Time (magazine)',
#   'Time Person of the Year',
#   'Killing of Muammar Gaddafi',
#   'Nasser Al-Mohammed Al-Sabah',
#   '2011–2012 Palestinian protests',
#   'Juan E. Méndez',
#   '2012 Yemeni presidential election',
#   'Islamism',
#   'Samuel Aranda',
#   'World Press Photo',
#   'Bahrain Independent Commission of Inquiry',
#   'El Mahalla El Kubra',
#   'Shia Islam',
#   'Turkish model',
#   'Libyan Crisis (2011–present)',
#   '2011 Tunisian Constituent Assembly election',
#   'Abu Kamal',
#   'Ennahda',
#   'Foreign Policy',
#   'Joseph Massad',
#   'Tuareg people',
#   'Death of Abdulredha Buhmaid',
#   'Habib el-Adly',
#   'March of loyalty to martyrs',
#   'Mohamed Morsi',
#   'Supreme Constitutional Court (Egypt)',
#   'Al-Hirak, Syria',
#   'Bahrain Defence Force',
#   'Bloody Thursday (Bahrain)',
#   'Casualties of the 2011 Bahraini uprising and its aftermath',
#   'Collective intelligence',
#   'Crowd psychology',
#   'Day of Rage (Bahrain)',
#   'Eastern Europe',
#   'Participatory design',
#   'Revolutions of 1989',
#   'Second World',
#   'Syrian civil war',
#   'Internet',
#   'Kuwait',
#   'Customs and Border Protection',
#   'Gulf states',
#   'Monarchy',
#   'Patrick Cockburn',
#   'Al-Islah (Yemen)',
#   'Democratization',
#   'Food',
#   'Post-coup unrest in Egypt (2013–2014)',
#   'Timeline of terrorism in Egypt (2013–present)',
#   'Iran–Saudi Arabia proxy conflict',
#   'Saudi Arabian–led intervention in Yemen',
#   'Counter-revolutionary',
#   'History of Libya under Muammar Gaddafi',
#   'Al-Qaeda',
#   'Connectionism',
#   "Metcalfe's law",
#   'South Yemen',
#   'Southern Movement',
#   'Subitizing',
#   'United States Department of Homeland Security',
#   'The New Yorker',
#   'U.S. Customs and Border Protection',
#   'Asef Bayat',
#   'Nicaragua',
#   'Condoleezza Rice',
#   'Frank G. Wisner',
#   'Marina Ottaway',
#   'Military dictatorship',
#   'Woodrow Wilson International Center for Scholars',
#   'Antonio Gramsci',
#   'April 6 Youth Movement',
#   'Civil society',
#   'Colonialism',
#   'Elias Khoury',
#   'Free market',
#   'Gene Sharp',
#   'H. A. Hellyer',
#   'International Center for Transitional Justice',
#   'International Republican Institute',
#   'Khalifa Haftar',
#   'London School of Economics',
#   'Non-governmental organization',
#   'Otpor',
#   'Saudi-led intervention in Bahrain',
#   'Social justice',
#   'The Economist',
#   'Think tank',
#   'Truth and Dignity Commission (Tunisia)',
#   'United States Agency for International Development',
#   'Yassin al-Haj Saleh',
#   'Halim Barakat',
#   'Autocracy',
#   'Authoritarianism',
#   'Southern Provinces',
#   'MENA',
#   'RAID',
#   'List of Facebook features',
#   'Rentier state',
#   'Corn ethanol',
#   'Death of Khaled Mohamed Saeed',
#   'The Atlantic',
#   'Wael Ghonim',
#   'Institution',
#   'Joel S. Migdal',
#   'Robert D. Putnam',
#   'Persian Gulf',
#   'YouTube',
#   'Yemeni civil war (2014–present)',
#   'Zeynep Tufekci',
#   'National Endowment for Democracy',
#   'Power vacuum',
#   'Societal collapse',
#   'Iraqi insurgency (2011–2013)',
#   'War in Iraq (2013–2017)',
#   'Great Recession',
#   'Islamic State',
#   'Muslim Brotherhood in Egypt',
#   'Proxy war',
#   'Rached Ghannouchi',
#   'State-building',
#   'Yemeni Crisis (2011–present)',
#   'Zaydism',
#   'Egyptian Crisis (2011–2014)',
#   'Houthi movement',
#   'Morocco',
#   'Djibouti',
#   '2011 Syrian Revolution',
#   'First Libyan Civil War',
#   '2014 Tunisian parliamentary election',
#   '2014 Tunisian presidential election',
#   'Nidaa Tounes',
#   'Open government',
#   'Arab League',
#   'Tunisian Constitution of 2014',
#   'Arab Winter',
#   'Deep state',
#   'Wisner',
#   'Alexander Cockburn',
#   'CounterPunch',
#   'Egyptian Initiative for Personal Rights',
#   'Tahrir Institute for Middle East Policy',
#   'The World (radio program)',
#   'Washington, D.C.',
#   'Jan Palach',
#   '2018–2022 Arab protests',
#   'Mosque',
#   'Syrian pound',
#   'Talk:Arab Spring',
#   'Activism',
#   'Ahmed Mansoor',
#   'Al Islah (United Arab Emirates)',
#   'Arbitrary arrest and detention',
#   'Enforced disappearance',
#   'Human rights defender',
#   'Journalist',
#   'Lawyer',
#   'Solitary confinement',
#   'Torture',
#   'Economic stagnation',
#   'Omar Suleiman (politician)',
#   'Battle of Misrata (2011)',
#   'World Bank',
#   'Literal translation',
#   'Rebellion',
#   'France',
#   'Hillary Clinton',
#   'Barack Obama',
#   '2019 Gaza economic protests',
#   "2019 Sudanese coup d'état",
#   'Khartoum massacre',
#   'Saddam Hussein',
#   'Sudanese Revolution',
#   'Sudanese transition to democracy',
#   'Transitional Sovereignty Council',
#   'Nonviolent resistance',
#   'Tripoli, Libya',
#   'Jamal Khashoggi',
#   'Insurgency',
#   'Prime Minister of Iraq'],
#  'C2': ['CASE 30',
#   'Copycat suicide',
#   'Egyptian Revolution',
#   'Kurdish',
#   'War on terror',
#   'Western Asia',
#   'Isfahan',
#   'Islamic Revolutionary Guard Corps',
#   'Mehdi Karroubi',
#   'Mir-Hossein Mousavi',
#   'Takbir',
#   'Tehran',
#   'Kayhan',
#   'Saiful Islam',
#   'Iranian Revolution',
#   'Regime change',
#   'Unemployment',
#   'Revolution',
#   'Poverty',
#   '2004–05 Palestinian local elections',
#   '2005 Palestinian presidential election',
#   '2006 Palestinian legislative election',
#   '2011 Ugandan general election',
#   'Abdullah of Saudi Arabia',
#   'Al-Shabaab (militant group)',
#   'Albania',
#   'André Mba Obame',
#   'Balkans',
#   'Beijing',
#   'Bolivia',
#   'Central Party School of the Chinese Communist Party',
#   'Chefchaouen',
#   'Committee to Protect Journalists',
#   'Damascus University',
#   'Douala',
#   'Edi Rama',
#   'Evo Morales',
#   'Federal Ministry of Defence (Germany)',
#   'Field agent',
#   'Gabon',
#   'General Secretary of the Chinese Communist Party',
#   'Government of China',
#   'Guelmim',
#   'Hafar al-Batin',
#   'Hawiye',
#   'Higher education',
#   'Ho Chi Minh City',
#   'Hu Jintao',
#   "Ibrahim Haji Jama Mee'aad",
#   'Ilir Meta',
#   'Interior minister',
#   'Internet censorship in China',
#   'Iraqi insurgency',
#   'Jamal al-Atassi',
#   'Jammu and Kashmir',
#   'Jammu and Kashmir Peoples Democratic Party',
#   'Janatha Vimukthi Peramuna',
#   'Karl-Theodor zu Guttenberg',
#   'Kashmir',
#   'Khalifa bin Hamad Al Thani',
#   'Kizza Besigye',
#   'Ksar el-Kebir',
#   'Larache',
#   'Lashkar-e-Taiba',
#   'Marrakesh',
#   'Larache',
#   'Mehbooba Mufti',
#   'Lashkar-e-Taiba',
#   'Mobile phone industry in China',
#   'Marrakesh',
#   'Mogadishu',
#   'Mehbooba Mufti',
#   'Mohamed Abdullahi Mohamed',
#   'Mobile phone industry in China',
#   'Mourning',
#   'Mogadishu',
#   'Next Palestinian legislative election',
#   'Mohamed Abdullahi Mohamed',
#   'Oruro',
#   'Mourning',
#   'Paul Biya',
#   'Next Palestinian legislative election',
#   'Plagiarism',
#   'Oruro',
#   'Prime minister',
#   'Paul Biya',
#   'Republic of Korea Armed Forces',
#   'Plagiarism',
#   'Ribal al-Assad',
#   'Prime minister',
#   'Rifaat al-Assad',
#   'Republic of Korea Armed Forces',
#   'SMS',
#   'Ribal al-Assad',
#   'Salaheddine Mezouar',
#   'Rifaat al-Assad',
#   'Sali Berisha',
#   'SMS',
#   'Sefrou',
#   'Salaheddine Mezouar',
#   'Shanghai',
#   'Sali Berisha',
#   'Sharif Sheikh Ahmed',
#   'Sefrou',
#   'Socialist Party of Albania',
#   'Shanghai',
#   'Syrian Communist Party',
#   'Sharif Sheikh Ahmed',
#   'Tahlia Street',
#   'Socialist Party of Albania',
#   'Tal al-Mallohi',
#   'Syrian Communist Party',
#   'Text messaging',
#   'Tahlia Street',
#   'The Christian Science Monitor',
#   'Tal al-Mallohi',
#   'Thesis',
#   'Text messaging',
#   'Thomson Reuters',
#   'The Christian Science Monitor',
#   'Tirana',
#   'Thesis',
#   'Transitional Federal Government of Somalia',
#   'Thomson Reuters',
#   'Tétouan',
#   'Tirana',
#   'Uganda',
#   'Transitional Federal Government of Somalia',
#   'Umma Islamic Party',
#   'Tétouan',
#   'United Nations Development Programme',
#   'Uganda',
#   'United Press International',
#   'Umma Islamic Party',
#   'Wen Jiabao',
#   'United Nations Development Programme',
#   'Yaoundé',
#   'United Press International',
#   'Yoweri Museveni',
#   'Wen Jiabao',
#   'Zimbabwe',
#   'Yaoundé',
#   '2011 South Sudanese independence referendum',
#   'Civil liberties',
#   'Domino theory',
#   'Government of Syria',
#   'Hassan Al-Turabi',
#   'Popular Congress Party',
#   'President',
#   'Raqqa',
#   'Yoweri Museveni'],
#  'C3': ['Battle of Wazzin',
#   'Democracy Index',
#   'List of current state leaders by date of assumption of office',
#   'Tunisian Army',
#   'United States Secretary of State',
#   'Jeremy Scahill',
#   'Johann Hari',
#   'John Pilger',
#   'Lebanese',
#   'March 8 Alliance',
#   'Michèle Alliot-Marie',
#   'NATO',
#   'Nir Rosen',
#   'Peru',
#   'Rami Makhlouf',
#   'Robert Fisk',
#   'United Nations Security Council',
#   'Western world',
#   'President of the United States',
#   'Misrata District',
#   'Skype',
#   'Foggy Bottom',
#   'Rosa Parks',
#   'The Daily Telegraph',
#   'Atar',
#   'Bedoon',
#   'Qatar',
#   'Israel',
#   'Africa',
#   'Anti-Gaddafi forces',
#   'Asia',
#   'Europe',
#   '2011–2012 Kurdish protests in Turkey',
#   'United Nations',
#   'David Cameron',
#   'Foreign Secretary',
#   'Prime Minister of the United Kingdom',
#   'Suez Canal',
#   'William Hague',
#   'The Wall Street Journal',
#   'Hamad bin Khalifa Al Thani',
#   'United Kingdom',
#   'Emir of Kuwait',
#   'Twitter',
#   '2008 Armenian presidential election',
#   'Armenia',
#   'Armenian National Congress',
#   'Azerbaijan',
#   'Karen Karapetyan',
#   'Levon Ter-Petrosyan',
#   'Republics of the Soviet Union',
#   'Serzh Sargsyan',
#   'Yerevan',
#   'Cabinet of Yemen',
#   'Economist Intelligence Unit',
#   'Freedom of the press',
#   'List of countries by GDP (nominal) per capita',
#   'List of shoe-throwing incidents',
#   'Media blackout',
#   'Mukalla',
#   'Riot police',
#   'Bouteflika',
#   'Agence France-Presse',
#   'Diplomatic cable',
#   'Saida',
#   'March 8',
#   'Youthquake',
#   'February 4',
#   'February 5',
#   'January 26',
#   'Jasmine Revolution',
#   'Djibouti City',
#   'Ismaïl Omar Guelleh',
#   'Al Arabiya',
#   'El-Obeid',
#   'Neelain University',
#   'Khartoum',
#   'Mubarak al-Fadil',
#   'South Sudan',
#   'Adam Smith',
#   'Economist',
#   "2012 Malian coup d'état",
#   'Mali',
#   'Tuareg rebellion (2012)',
#   '2005 Ahvaz unrest',
#   'Ahvaz',
#   'Azawad',
#   'Kassala',
#   'Shirin Ebadi',
#   'Anti-communism',
#   'Austerity',
#   'University of Khartoum',
#   'Fayez Tarawneh',
#   'Governance of the Gaza Strip',
#   'Democracy',
#   'Al Hoceima',
#   'Hamas',
#   'Mahmoud Abbas',
#   'Fez, Morocco',
#   'Jizan',
#   'Samtah',
#   'Human rights in Saudi Arabia',
#   'Early insurgency phase of the Syrian civil war',
#   'Kamal Ganzouri',
#   'Madaya',
#   '2011 Moroccan general election',
#   'Abbas El Fassi',
#   'Al-Erada Square',
#   'Aoujeft',
#   'Atar, Mauritania',
#   'Bedouin',
#   'Fatah',
#   'National Assembly (Kuwait)',
#   'Palestinian refugees',
#   'Ramallah',
#   'Taieb Cherkaoui',
#   'Awn Al-Khasawneh',
#   'Nakba',
#   'Nakba Day',
#   '2015 Saudi Arabian municipal elections',
#   'Consultative Assembly of Saudi Arabia',
#   'Dammam',
#   'Eastern Province, Saudi Arabia',
#   'House of Saud',
#   'Labor rights',
#   'Laghouat',
#   'Ministry of home affairs',
#   'Nayef bin Abdulaziz',
#   'Tabuk, Saudi Arabia',
#   'Taif',
#   'UAE Five',
#   'Universal suffrage',
#   "Women's suffrage",
#   '2011 Algerian self-immolations',
#   'First Intifada',
#   '2012 Algerian legislative election',
#   'Movement of Society for Peace',
#   'Al-Khalidiya',
#   "Ba'athist Iraq",
#   'Kuwait City',
#   'Kuwaiti dinar',
#   'Amnesty International',
#   'Federal National Council',
#   'Gaza Strip',
#   'December 17',
#   'January 4',
#   'Arab nationalism',
#   'Palestinian Intifada',
#   'Palestine 194',
#   'Fez',
#   'First Cabinet of Saad Hariri',
#   'Israel Defense Forces',
#   'Najib Mikati',
#   'Saad Hariri',
#   'Second Cabinet of Najib Mikati',
#   'Just Journalism',
#   'Manal al-Sharif',
#   'Massacre',
#   'Michel Suleiman',
#   'Navi Pillay',
#   'Palestinian right of return',
#   'Syrian Social Nationalist Party',
#   'Women to drive movement',
#   'Golan Heights',
#   'Bayda, Libya',
#   '2012–13 Palestinian local elections',
#   'Al-Karak',
#   'Amman',
#   'As-Salt',
#   'Baghdad',
#   'Casablanca',
#   'Green Zone',
#   'Haaretz',
#   'Irbid',
#   'Karbala',
#   "Ma'an",
#   'Marouf al-Bakhit',
#   'Mosul',
#   'Rabat',
#   'Sabah Al-Ahmad Al-Jaber Al-Sabah',
#   'Salalah',
#   'Salam Fayyad',
#   'Sohar',
#   'Tear gas',
#   'Algiers',
#   'Bordj Menaïel',
#   'Boukhadra',
#   'Béjaïa',
#   'Friday prayer',
#   'Jeddah',
#   'Left-wing politics',
#   'Mohamed Ould Abdel Aziz',
#   'Rally for Culture and Democracy',
#   'Samir Rifai',
#   'Tangier',
#   '2011 Saudi Arabian municipal elections',
#   'Al-Awamiyah',
#   'Aleg',
#   'Beirut',
#   'Confessionalism (politics)',
#   'Hofuf',
#   'March 14 Alliance',
#   'Ministry of Interior (Saudi Arabia)',
#   'Politics of Lebanon',
#   'Qaboos bin Said',
#   'Qatif',
#   'Royal Army of Oman',
#   'Royal Oman Police',
#   'Secularism in France',
#   'Special Tribunal for Lebanon',
#   'United Arab Emirates',
#   'Zouérat',
#   'Moulaye Ould Mohamed Laghdaf',
#   'Sidon',
#   'WikiLeaks',
#   '2011 Lebanese protests',
#   'List of heads of state of Sudan',
#   'Azaz',
#   'Human Rights Watch',
#   'Human Rights First',
#   'Physicians for Human Rights',
#   'Freedom House',
#   '2011 Indian anti-corruption movement',
#   'Anna Hazare',
#   'Parliament of India',
#   'The Lokpal and Lokayuktas Act, 2013',
#   'Youth',
#   'Climate change',
#   'Constitution of Tunisia',
#   'Standard Moroccan Amazigh',
#   'Intifada',
#   '2011 Israeli social justice protests',
#   'June 2013 Egyptian protests',
#   'Houthi takeover in Yemen',
#   'Moshe Dayan Center for Middle Eastern and African Studies',
#   'Free Syrian Army',
#   'Syrian Army',
#   'Al-Qusayr, Syria',
#   'Al-Rastan',
#   'Al-Zabadani',
#   'Harasta',
#   'Idlib',
#   'Idlib Governorate',
#   'Maher al-Assad',
#   'Rif Dimashq Governorate',
#   'Aleppo Governorate',
#   'Sarmin',
#   'Daraa Governorate',
#   'Deir ez-Zor Governorate',
#   'Homs',
#   'Saqba',
#   'Saraqib',
#   'Madaya, Syria',
#   'Civil war',
#   'Riot',
#   'Political demonstration',
#   'Protest',
#   'Third International Theory',
#   'Absolute monarchy',
#   'Opposition (politics)',
#   'Arab world',
#   'Western Sahara',
#   'Art and politics in post-2011 Tunisia',
#   'Gezi Park protests',
#   'Kosovo',
#   'Arab wedding',
#   'Anti-Americanism',
#   'Anti-Western sentiment',
#   'Anti-Zionism',
#   'Cuban Revolution',
#   'Al Jazeera English',
#   'Conservatism in the United States',
#   'Julian Assange',
#   'United Nations General Assembly',
#   '2011 Burkina Faso protests',
#   '2011 Chinese pro-democracy protests',
#   '2011 Georgian protests',
#   '2011–2013 Maldives political crisis',
#   'Anti-austerity movement in Spain',
#   'History of Croatia (1995–present)',
#   'South Caucasus',
#   'Sub-Saharan Africa',
#   '2011 Armenian protests',
#   '2011 Azerbaijani protests',
#   'Berbers',
#   'Coptic Orthodox Church',
#   'Copts',
#   'Czechoslovakia',
#   'Darfur',
#   'History of Czechoslovakia (1948–1989)',
#   'History of the Jews in Tunisia',
#   'Jews',
#   'Kurdistan Regional Government',
#   'Pope Shenouda III of Alexandria',
#   'Martyr',
#   'Noam Chomsky',
#   '2009 Iranian presidential election protests',
#   'International Monetary Fund',
#   'Famine',
#   'Internet censorship',
#   '2011 Albanian opposition demonstrations',
#   '2011–2012 Iranian protests',
#   'Kurds',
#   'Saudi',
#   'Syrian civil war spillover in Lebanon',
#   'Kyrgyz Revolution of 2010',
#   'Slavoj Žižek',
#   'Goodluck Jonathan',
#   'Nigeria',
#   'Occupy Nigeria',
#   '15 October 2011 global protests',
#   'Occupy Wall Street',
#   'Hypocrisy',
#   '2011 Moroccan constitutional referendum',
#   'Berber languages',
#   'Berber Spring',
#   'Presidency of Barack Obama',
#   'Maldives',
#   '2007–2008 world food price crisis',
#   'Food security',
#   'Literacy',
#   'Turkey',
#   'Youthquake (movement)',
#   '2011 Israeli border demonstrations',
#   'Anachronism',
#   '2011 Khuzestan protests',
#   'Iranian Arabs',
#   'David Ignatius',
#   'War']}

# %%
def get_cluster_classes(den, label='ivl'):
    cluster_idxs = defaultdict(list)
    for c, pi in zip(den['color_list'], den['icoord']):
        for leg in pi[1:3]:
            i = (leg - 5.0) / 10.0
            if abs(i - int(i)) < 1e-5:
                cluster_idxs[c].append(int(i))
    
    cluster_classes = Clusters()
    for c, l in cluster_idxs.items():
        i_l = [den[label][i] for i in l]
        cluster_classes[c] = i_l
    
    return cluster_classes

# %%
figsize(12, 4)
den = dendrogram(link, labels=pairDf_en.index)#, abv_threshold_color='#AAAAAA')
plt.xticks(rotation=90)
sns.despine(**no_spine);

plt.tight_layout()
#plt.savefig('tree2.png');

# %%
get_cluster_classes(Z)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [96], in <cell line: 1>()
# ----> 1 get_cluster_classes(Z)
#
# Input In [66], in get_cluster_classes(den, label)
#       1 def get_cluster_classes(den, label='ivl'):
#       2     cluster_idxs = defaultdict(list)
# ----> 3     for c, pi in zip(den['color_list'], den['icoord']):
#       4         for leg in pi[1:3]:
#       5             i = (leg - 5.0) / 10.0
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
clusterPlt = sns.clustermap(Z)
clusterPlt.fig.suptitle("Outlinks with Spatial Distance, cluster")
# clusterPlt.savefig("03out_spatialOutlink_cluster.png")

clusterPlt

# %%
everything = wf.get_all_page_revisions('Arab Spring')

# %%
# 2014-05-31
# 2021-04-30 - send spike in clusdter 4
# 2022-12-31 - last spike in cluster 4

# Ensure df['date'] is a Series with dtype datetime64[ns]:
everything['timestamp'] = pd.to_datetime(everything['timestamp'])  

startdate = pd.to_datetime("2022-11-30").date()
enddate = pd.to_datetime("2023-01-05").date()

#greater than the start date and smaller than the end date
mask = (everything['date'] > startdate) & (everything['date'] <= enddate)

df = everything.loc[mask]

# %%
#get the revid and time and get the outlinks in each revid
df2 = pd.DataFrame()

df2['revid'] = df['revid']
df2['time'] = df['timestamp']

df2.head()
# Out:
#            revid                      time
# 9802  1124986313 2022-12-01 16:13:46+00:00
# 9803  1124986560 2022-12-01 16:15:21+00:00
# 9804  1126196106 2022-12-08 01:43:19+00:00
# 9805  1126326407 2022-12-08 19:19:25+00:00
# 9806  1130279099 2022-12-29 11:58:49+00:00

# %%
from tqdm import tqdm
revLinksDict = {}

for i in tqdm(df2['revid']):
    outlinks = wf.get_revision_outlinks(i)
    outlinks_clean = wf.resolve_redirects(outlinks)
    revLinksDict[i] = outlinks_clean
# Out:
# 100%|█████████████████████████████████████████████| 8/8 [01:03<00:00,  7.95s/it]

# %%
revLinksDict
# 1124986313
# 1124986313
# Out:
# {1124986313: ['Algeria',
#   'Arabic',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Arab world',
#   'Ali Abdullah Saleh',
#   'State of Palestine',
#   'Power vacuum',
#   'Saudi Arabia',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Syrian pound',
#   'Rebellion',
#   'Insurgency',
#   'Southern Provinces',
#   'Literal translation',
#   'Economic stagnation',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Facebook',
#   'Egypt',
#   'Revolutions of 1848',
#   'Djibouti',
#   'Mauritania',
#   'Bahrain',
#   'Nonviolent resistance',
#   'Authoritarianism',
#   'Tunisian Revolution',
#   'Syrian civil war',
#   'Egyptian Crisis (2011–2014)',
#   'Ash-shab yurid isqat an-nizam',
#   "2013 Egyptian coup d'état",
#   'Post-coup unrest in Egypt (2013–2014)',
#   'Arab Winter',
#   'Counter-revolutionary',
#   'Libyan Crisis (2011–present)',
#   'Yemeni Crisis (2011–present)',
#   'Yemeni civil war (2014–present)',
#   'Timeline of terrorism in Egypt (2013–present)',
#   'Second Arab Spring',
#   'Cairo',
#   'Human rights',
#   'Internet',
#   'Islamism',
#   'Libya',
#   'Mosque',
#   'Prague Spring',
#   'Tunisia',
#   'Eastern Europe',
#   'Hosni Mubarak',
#   'United States Department of Homeland Security',
#   "Metcalfe's law",
#   'Political corruption',
#   'El Mahalla El Kubra',
#   'The Atlantic',
#   'Crowd psychology',
#   'Second World',
#   'Connectionism',
#   'National Endowment for Democracy',
#   'Democratization',
#   'Yemen',
#   'Jan Palach',
#   'Foreign Policy',
#   'Subitizing',
#   'U.S. Customs and Border Protection',
#   'Participatory design',
#   'Gafsa',
#   'YouTube',
#   'Revolutions of 1989',
#   'Iraq War',
#   'Joseph Massad',
#   'Facebook',
#   'Egypt',
#   'Liberal democracy',
#   'Corn ethanol',
#   'Civil resistance',
#   'List of Facebook features',
#   'Bahrain',
#   'Great Recession',
#   'Collective intelligence',
#   'Marc Lynch',
#   'Death of Khaled Mohamed Saeed',
#   'Mohamed Bouazizi',
#   'Wael Ghonim',
#   'Al Jazeera',
#   'Zeynep Tufekci',
#   'Algeria',
#   'Arabs',
#   'Libya',
#   'Tunisia',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Tuareg people',
#   'Ali Abdullah Saleh',
#   'President of Egypt',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Laayoune',
#   'Sahrawis',
#   'Self-immolation',
#   'Sirte',
#   'Jordan',
#   'Egypt',
#   'Tahrir Square',
#   'Abdrabbuh Mansur Hadi',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Mohamed Bouazizi',
#   '2011 Egyptian revolution',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Libyan civil war (2011)',
#   '2011 Bahraini uprising',
#   '2011 Iraqi protests',
#   '2011 Djiboutian protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   '2011–2012 Saudi Arabian protests',
#   'Bab al-Azizia',
#   'Gdeim Izik protest camp',
#   'Kuwaiti protests (2011–2012)',
#   'National Transitional Council',
#   'Impact of the Arab Spring',
#   '2011–2012 Palestinian protests',
#   '2011 Western Saharan protests',
#   '2011–2012 Mauritanian protests',
#   'Syrian revolution',
#   'Revolutionary wave',
#   'Political freedom',
#   'Iran',
#   'Manama',
#   'North Africa',
#   'Shia Islam',
#   'Sudan',
#   'Time (magazine)',
#   'Hosni Mubarak',
#   'Bahrain Defence Force',
#   'Abdullah II of Jordan',
#   'Mohamed ElBaradei',
#   'Time Person of the Year',
#   'State of emergency',
#   'Hamad bin Isa Al Khalifa',
#   'Omar al-Bashir',
#   'Prime Minister of Egypt',
#   'King of Bahrain',
#   'Parliament of Egypt',
#   'Media activism',
#   'World Press Photo',
#   'Juan E. Méndez',
#   'Nasser Al-Mohammed Al-Sabah',
#   'Nouri al-Maliki',
#   'Social media',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Human rights in Bahrain',
#   'Omar Suleiman (politician)',
#   'Tahrir Square',
#   'Peninsula Shield Force',
#   '2012 Egyptian presidential election',
#   'Nobel Peace Prize',
#   'Emergency law in Egypt',
#   'Tawakkol Karman',
#   'Supreme Council of the Armed Forces',
#   'Pearl Roundabout',
#   '2011–2012 Saudi Arabian protests',
#   'Essam Sharaf',
#   'Bahrain Independent Commission of Inquiry',
#   '2011 Nobel Peace Prize',
#   'Bloody Thursday (Bahrain)',
#   'Casualties of the 2011 Bahraini uprising and its aftermath',
#   'Samuel Aranda',
#   'Day of Rage (Bahrain)',
#   'March of loyalty to martyrs',
#   'Death of Abdulredha Buhmaid',
#   'Mali War',
#   'Constitution of Egypt',
#   'Damascus',
#   'Tripoli, Libya',
#   'Muammar Gaddafi',
#   'Washington, D.C.',
#   'Aleppo',
#   'Libyan Desert',
#   'Benghazi',
#   'Daraa',
#   'Gulf of Sidra',
#   'No-fly zone',
#   'Misrata',
#   'Tripolitania',
#   'Saif al-Islam Gaddafi',
#   'Sabha, Libya',
#   'The World (radio program)',
#   'Supreme Constitutional Court (Egypt)',
#   'United States',
#   'Habib el-Adly',
#   'History of Libya under Muammar Gaddafi',
#   'France',
#   'Sirte',
#   'Bani Walid',
#   'Syria',
#   'Al-Hasakah',
#   'Nafusa Mountains',
#   'Egyptian Initiative for Personal Rights',
#   'Brega',
#   'Ajdabiya',
#   'Supreme Council of the Armed Forces',
#   'Battle of Misrata (2011)',
#   'National Transitional Council',
#   '2011 military intervention in Libya',
#   'United Nations Security Council Resolution 1973',
#   'First Gulf of Sidra offensive',
#   'Battle of Brega–Ajdabiya road',
#   'Battle of Sabha',
#   'Mohamed Morsi',
#   'Battle of Tripoli (2011)',
#   'Battle of Sirte (2011)',
#   'Battle of Bani Walid',
#   'Killing of Muammar Gaddafi',
#   "Arab Socialist Ba'ath Party – Syria Region",
#   '2012–2013 Egyptian protests',
#   "2013 Egyptian coup d'état",
#   'Libyan Crisis (2011–present)',
#   'Tahrir Institute for Middle East Policy',
#   'Al-Qaeda',
#   'Food',
#   'Political freedom',
#   'Lawyer',
#   'Inflation',
#   'Torture',
#   'Journalist',
#   'Ali Abdullah Saleh',
#   'Solitary confinement',
#   'State of emergency',
#   'Saudi Arabia',
#   'Bashar al-Assad',
#   'Zine El Abidine Ben Ali',
#   'Mohamed Ghannouchi',
#   'Democratic Constitutional Rally',
#   'President of Tunisia',
#   'Hama',
#   'Enforced disappearance',
#   'South Yemen',
#   'Deir ez-Zor',
#   'Sidi Bouzid',
#   'Habitability',
#   'Abu Kamal',
#   'Human rights defender',
#   'Federal National Council',
#   'Human rights in Yemen',
#   'Open government',
#   'Arbitrary arrest and detention',
#   'Sanaa',
#   'Amnesty International',
#   'Freedom of speech',
#   'Constitution of Yemen',
#   'Southern Movement',
#   'Mohamed Bouazizi',
#   '2014 Tunisian presidential election',
#   'Syrian civil war',
#   'Ennahda',
#   'Beji Caid Essebsi',
#   '2011 Tunisian Constituent Assembly election',
#   'Al-Hirak, Syria',
#   'Nidaa Tounes',
#   'Suheir Atassi',
#   'Al Islah (United Arab Emirates)',
#   'Activism',
#   '2014 Tunisian parliamentary election',
#   'Tunisian Constitution of 2014',
#   'Ahmed Mansoor',
#   'Algeria',
#   'Gaza Strip',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Persian Gulf',
#   'Sudan',
#   'Saddam Hussein',
#   'Tunisia',
#   'The New Yorker',
#   'Aden',
#   'Riyadh',
#   'Arab League',
#   'Prime Minister of Iraq',
#   'Gulf Cooperation Council',
#   'Human Development Index',
#   'Xinhua News Agency',
#   'Institution',
#   'Saudi Arabia',
#   'Omar al-Bashir',
#   "General People's Congress (Yemen)",
#   'Taiz',
#   'Robert D. Putnam',
#   'BBC News',
#   'Rentier state',
#   'Elections in Yemen',
#   'Arab states of the Persian Gulf',
#   'Societal collapse',
#   'Hashid',
#   'Syria',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Halim Barakat',
#   'Abdrabbuh Mansur Hadi',
#   'Talk:Arab Spring',
#   'Tawakkol Karman',
#   'Al Jazeera',
#   '2012 Yemeni presidential election',
#   'Joel S. Migdal',
#   'World Bank',
#   'Yemeni civil war (2014–present)',
#   'Saudi-led intervention in the Yemeni civil war',
#   'Sudanese revolution',
#   '2019 Gaza economic protests',
#   'Second Arab Spring',
#   'Colonialism',
#   'Dictatorship',
#   'Free market',
#   'Muslim Brotherhood',
#   'Nicaragua',
#   'Tunisia',
#   'Tripoli, Libya',
#   'Think tank',
#   'Non-governmental organization',
#   'Social justice',
#   'Autocracy',
#   'The Economist',
#   'Hosni Mubarak',
#   'Antonio Gramsci',
#   'London School of Economics',
#   'United States Agency for International Development',
#   'Military dictatorship',
#   'Condoleezza Rice',
#   'Civil society',
#   'National Endowment for Democracy',
#   'Abdelaziz Bouteflika',
#   'Omar al-Bashir',
#   'Gene Sharp',
#   'Barack Obama',
#   'Otpor',
#   'International Republican Institute',
#   'Woodrow Wilson International Center for Scholars',
#   'Asef Bayat',
#   'Middle East and North Africa',
#   'Elias Khoury',
#   'Hillary Clinton',
#   'International Center for Transitional Justice',
#   'Frank G. Wisner',
#   'H. A. Hellyer',
#   'Omar Suleiman (politician)',
#   'April 6 Youth Movement',
#   'Muslim Brotherhood in Egypt',
#   'Wael Ghonim',
#   'Supreme Council of the Armed Forces',
#   'Ennahda',
#   'Khalifa Haftar',
#   'Yassin al-Haj Saleh',
#   'Mohamed Morsi',
#   'Saudi-led intervention in Bahrain',
#   'Truth and Dignity Commission (Tunisia)',
#   "2019 Sudanese coup d'état",
#   'Khartoum massacre',
#   'Sudanese transition to democracy',
#   'Transitional Sovereignty Council',
#   'Algeria',
#   'Hezbollah',
#   'ISBN',
#   'Libya',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Tunisia',
#   'Foreign Affairs',
#   'Yemen',
#   'Digital object identifier',
#   'Zaydism',
#   'Proxy war',
#   'State-building',
#   'Jack Goldstone',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Islamic State',
#   'Rached Ghannouchi',
#   'Houthi movement',
#   'Bahrain',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Al-Islah (Yemen)',
#   'Libyan civil war (2011)',
#   'Muslim Brotherhood in Egypt',
#   'Syrian civil war',
#   '2011 Bahraini uprising',
#   'Egyptian Crisis (2011–2014)',
#   '2011 Iraqi protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   'Kuwaiti protests (2011–2012)',
#   'Andrew Reynolds (political scientist)',
#   'Jadaliyya',
#   "2013 Egyptian coup d'état",
#   'Semantic Scholar',
#   'Iran–Saudi Arabia proxy conflict',
#   'Marina Ottaway',
#   'ISBN',
#   'Peer review',
#   'The New York Times',
#   'CNN',
#   'Financial Times',
#   'Der Spiegel',
#   'Council on Foreign Relations',
#   'ISSN',
#   'Digital object identifier',
#   'Carnegie Endowment for International Peace',
#   'Timothy Garton Ash',
#   'BBC News',
#   'Social Science Research Network',
#   'Pluto Press',
#   'Research Papers in Economics',
#   'Social media',
#   'Hürriyet Daily News',
#   'Armed Forces & Society',
#   'The National (Abu Dhabi)',
#   'Robert Pelletreau',
#   'Robert Struble Jr.',
#   'Reuters',
#   'The Guardian',
#   'BBC',
#   'Qantara.de',
#   'Adam Roberts (scholar)',
#   'Al Jazeera',
#   'Interface: A Journal for and About Social Movements',
#   'Ruaridh Arrow',
#   'Semantic Scholar'],
#  1124986560: ['Algeria',
#   'Arabic',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Arab world',
#   'Ali Abdullah Saleh',
#   'State of Palestine',
#   'Power vacuum',
#   'Saudi Arabia',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Rebellion',
#   'Insurgency',
#   'Southern Provinces',
#   'Literal translation',
#   'Economic stagnation',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Facebook',
#   'Egypt',
#   'Islamic State',
#   'Djibouti',
#   'Mauritania',
#   'Bahrain',
#   'Nonviolent resistance',
#   'Authoritarianism',
#   'Tunisian Revolution',
#   'Syrian civil war',
#   'Egyptian Crisis (2011–2014)',
#   'Ash-shab yurid isqat an-nizam',
#   'Iraqi insurgency (2011–2013)',
#   "2013 Egyptian coup d'état",
#   'Post-coup unrest in Egypt (2013–2014)',
#   'Arab Winter',
#   'Counter-revolutionary',
#   'War in Iraq (2013–2017)',
#   'Libyan Crisis (2011–present)',
#   'Yemeni Crisis (2011–present)',
#   'Yemeni civil war (2014–present)',
#   'Timeline of terrorism in Egypt (2013–present)',
#   'Human rights',
#   'Internet',
#   'Islamism',
#   'Libya',
#   'North Africa',
#   'Prague Spring',
#   'Eastern Europe',
#   'United States Department of Homeland Security',
#   "Metcalfe's law",
#   'Political corruption',
#   'The Atlantic',
#   'Crowd psychology',
#   'Second World',
#   'Connectionism',
#   'National Endowment for Democracy',
#   'Democratization',
#   'Yemen',
#   'Syrian pound',
#   'Jan Palach',
#   'Foreign Policy',
#   'Subitizing',
#   'U.S. Customs and Border Protection',
#   'Participatory design',
#   'Arab states of the Persian Gulf',
#   'YouTube',
#   'Revolutions of 1989',
#   'Iraq War',
#   'Joseph Massad',
#   'Facebook',
#   'Egypt',
#   'Liberal democracy',
#   'Corn ethanol',
#   'Revolutions of 1848',
#   'Civil resistance',
#   'List of Facebook features',
#   'Bahrain',
#   'Great Recession',
#   'Collective intelligence',
#   'Marc Lynch',
#   'Death of Khaled Mohamed Saeed',
#   'Mohamed Bouazizi',
#   'Wael Ghonim',
#   'Syrian civil war',
#   'Al Jazeera',
#   'Turkish model',
#   'Zeynep Tufekci',
#   'Second Arab Spring',
#   'Algeria',
#   'Arabs',
#   'Cairo',
#   'Mosque',
#   'Tunisia',
#   'Hosni Mubarak',
#   'El Mahalla El Kubra',
#   'President of Egypt',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Laayoune',
#   'Sahrawis',
#   'Self-immolation',
#   'Gafsa',
#   'Jordan',
#   'Egypt',
#   'Tahrir Square',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Mohamed Bouazizi',
#   '2011 Egyptian revolution',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Libyan civil war (2011)',
#   '2011 Bahraini uprising',
#   '2011 Iraqi protests',
#   '2011 Djiboutian protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   '2011–2012 Saudi Arabian protests',
#   'Gdeim Izik protest camp',
#   'Kuwaiti protests (2011–2012)',
#   'Impact of the Arab Spring',
#   '2011–2012 Palestinian protests',
#   '2011 Western Saharan protests',
#   '2011–2012 Mauritanian protests',
#   'Syrian revolution',
#   'Revolutionary wave',
#   'Political freedom',
#   'Iran',
#   'Libya',
#   'Manama',
#   'North Africa',
#   'Shia Islam',
#   'Sudan',
#   'Time (magazine)',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Bahrain Defence Force',
#   'Tuareg people',
#   'Abdullah II of Jordan',
#   'Mohamed ElBaradei',
#   'Time Person of the Year',
#   'Ali Abdullah Saleh',
#   'State of emergency',
#   'Hamad bin Isa Al Khalifa',
#   'Omar al-Bashir',
#   'King of Bahrain',
#   'Media activism',
#   'World Press Photo',
#   'Juan E. Méndez',
#   'Nasser Al-Mohammed Al-Sabah',
#   'Nouri al-Maliki',
#   'Social media',
#   'Sirte',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Human rights in Bahrain',
#   'Peninsula Shield Force',
#   '2012 Egyptian presidential election',
#   'Nobel Peace Prize',
#   'Abdrabbuh Mansur Hadi',
#   'Tawakkol Karman',
#   'Pearl Roundabout',
#   '2011–2012 Saudi Arabian protests',
#   'Bab al-Azizia',
#   'National Transitional Council',
#   'Bahrain Independent Commission of Inquiry',
#   '2011 Nobel Peace Prize',
#   'Bloody Thursday (Bahrain)',
#   'Casualties of the 2011 Bahraini uprising and its aftermath',
#   'Samuel Aranda',
#   'Day of Rage (Bahrain)',
#   'March of loyalty to martyrs',
#   'Death of Abdulredha Buhmaid',
#   'Mali War',
#   'Tripoli, Libya',
#   'Muammar Gaddafi',
#   'Washington, D.C.',
#   'Libyan Desert',
#   'Benghazi',
#   'Gulf of Sidra',
#   'No-fly zone',
#   'Misrata',
#   'Tripolitania',
#   'Prime Minister of Egypt',
#   'Saif al-Islam Gaddafi',
#   'Sabha, Libya',
#   'Parliament of Egypt',
#   'The World (radio program)',
#   'Supreme Constitutional Court (Egypt)',
#   'United States',
#   'Habib el-Adly',
#   'History of Libya under Muammar Gaddafi',
#   'France',
#   'Sirte',
#   'Bani Walid',
#   'Nafusa Mountains',
#   'Egyptian Initiative for Personal Rights',
#   'Brega',
#   'Omar Suleiman (politician)',
#   'Tahrir Square',
#   'Ajdabiya',
#   'Emergency law in Egypt',
#   'Supreme Council of the Armed Forces',
#   'Battle of Misrata (2011)',
#   'National Transitional Council',
#   'Essam Sharaf',
#   '2011 military intervention in Libya',
#   'United Nations Security Council Resolution 1973',
#   'First Gulf of Sidra offensive',
#   'Battle of Brega–Ajdabiya road',
#   'Battle of Sabha',
#   'Mohamed Morsi',
#   'Battle of Tripoli (2011)',
#   'Battle of Sirte (2011)',
#   'Battle of Bani Walid',
#   'Killing of Muammar Gaddafi',
#   '2012–2013 Egyptian protests',
#   "2013 Egyptian coup d'état",
#   'Constitution of Egypt',
#   'Tahrir Institute for Middle East Policy',
#   'Damascus',
#   'Food',
#   'Political freedom',
#   'Lawyer',
#   'Inflation',
#   'Torture',
#   'Journalist',
#   'Aleppo',
#   'Solitary confinement',
#   'State of emergency',
#   'Daraa',
#   'Saudi Arabia',
#   'Bashar al-Assad',
#   'Zine El Abidine Ben Ali',
#   'Mohamed Ghannouchi',
#   'Democratic Constitutional Rally',
#   'President of Tunisia',
#   'Hama',
#   'Enforced disappearance',
#   'South Yemen',
#   'Deir ez-Zor',
#   'Sidi Bouzid',
#   'Habitability',
#   'Abu Kamal',
#   'Human rights defender',
#   'Federal National Council',
#   'Syria',
#   'Al-Hasakah',
#   'Open government',
#   'Arbitrary arrest and detention',
#   'Amnesty International',
#   'Freedom of speech',
#   'Mohamed Bouazizi',
#   '2014 Tunisian presidential election',
#   'Syrian civil war',
#   'Ennahda',
#   'Beji Caid Essebsi',
#   '2011 Tunisian Constituent Assembly election',
#   "Arab Socialist Ba'ath Party – Syria Region",
#   'Al-Hirak, Syria',
#   'Nidaa Tounes',
#   'Suheir Atassi',
#   'Al Islah (United Arab Emirates)',
#   'Activism',
#   '2014 Tunisian parliamentary election',
#   'Tunisian Constitution of 2014',
#   'Libyan Crisis (2011–present)',
#   'Ahmed Mansoor',
#   'Algeria',
#   'Al-Qaeda',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Persian Gulf',
#   'Sudan',
#   'The New Yorker',
#   'Aden',
#   'Riyadh',
#   'Arab League',
#   'Ali Abdullah Saleh',
#   'Gulf Cooperation Council',
#   'Human Development Index',
#   'Xinhua News Agency',
#   'Institution',
#   'Saudi Arabia',
#   "General People's Congress (Yemen)",
#   'Taiz',
#   'Robert D. Putnam',
#   'South Yemen',
#   'BBC News',
#   'Rentier state',
#   'Elections in Yemen',
#   'Arab states of the Persian Gulf',
#   'Societal collapse',
#   'Hashid',
#   'Human rights in Yemen',
#   'Syria',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Halim Barakat',
#   'Sanaa',
#   'Constitution of Yemen',
#   'Southern Movement',
#   'Abdrabbuh Mansur Hadi',
#   'Talk:Arab Spring',
#   'Tawakkol Karman',
#   'Al Jazeera',
#   '2012 Yemeni presidential election',
#   'Joel S. Migdal',
#   'World Bank',
#   'Yemeni civil war (2014–present)',
#   'Saudi-led intervention in the Yemeni civil war',
#   'Second Arab Spring',
#   'Free market',
#   'Gaza Strip',
#   'Muslim Brotherhood',
#   'Nicaragua',
#   'Sudan',
#   'Saddam Hussein',
#   'Tunisia',
#   'Tripoli, Libya',
#   'Think tank',
#   'Non-governmental organization',
#   'Social justice',
#   'The Economist',
#   'Hosni Mubarak',
#   'Antonio Gramsci',
#   'London School of Economics',
#   'United States Agency for International Development',
#   'Military dictatorship',
#   'Prime Minister of Iraq',
#   'Civil society',
#   'National Endowment for Democracy',
#   'Abdelaziz Bouteflika',
#   'Omar al-Bashir',
#   'Gene Sharp',
#   'Barack Obama',
#   'Otpor',
#   'International Republican Institute',
#   'Asef Bayat',
#   'Elias Khoury',
#   'Hillary Clinton',
#   'International Center for Transitional Justice',
#   'Frank G. Wisner',
#   'Omar Suleiman (politician)',
#   'April 6 Youth Movement',
#   'Muslim Brotherhood in Egypt',
#   'Wael Ghonim',
#   'Supreme Council of the Armed Forces',
#   'Ennahda',
#   'Khalifa Haftar',
#   'Yassin al-Haj Saleh',
#   'Mohamed Morsi',
#   'Saudi-led intervention in Bahrain',
#   'Truth and Dignity Commission (Tunisia)',
#   'Sudanese revolution',
#   '2019 Gaza economic protests',
#   "2019 Sudanese coup d'état",
#   'Khartoum massacre',
#   'Sudanese transition to democracy',
#   'Transitional Sovereignty Council',
#   'Algeria',
#   'Colonialism',
#   'Dictatorship',
#   'Hezbollah',
#   'Libya',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Tunisia',
#   'Autocracy',
#   'Condoleezza Rice',
#   'Yemen',
#   'Zaydism',
#   'Proxy war',
#   'Woodrow Wilson International Center for Scholars',
#   'Middle East and North Africa',
#   'State-building',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Islamic State',
#   'Rached Ghannouchi',
#   'H. A. Hellyer',
#   'Houthi movement',
#   'Bahrain',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Al-Islah (Yemen)',
#   'Libyan civil war (2011)',
#   'Muslim Brotherhood in Egypt',
#   'Syrian civil war',
#   '2011 Bahraini uprising',
#   'Egyptian Crisis (2011–2014)',
#   '2011 Iraqi protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   'Kuwaiti protests (2011–2012)',
#   "2013 Egyptian coup d'état",
#   'Iran–Saudi Arabia proxy conflict',
#   'Marina Ottaway'],
#  1126196106: ['Algeria',
#   'Arabic',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Arab world',
#   'Ali Abdullah Saleh',
#   'State of Palestine',
#   'Power vacuum',
#   'Saudi Arabia',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Rebellion',
#   'Insurgency',
#   'Southern Provinces',
#   'Literal translation',
#   'Economic stagnation',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Facebook',
#   'Egypt',
#   'Islamic State',
#   'Djibouti',
#   'Mauritania',
#   'Bahrain',
#   'Nonviolent resistance',
#   'Authoritarianism',
#   'Tunisian Revolution',
#   'Syrian civil war',
#   'Egyptian Crisis (2011–2014)',
#   'Ash-shab yurid isqat an-nizam',
#   'Iraqi insurgency (2011–2013)',
#   "2013 Egyptian coup d'état",
#   'Post-coup unrest in Egypt (2013–2014)',
#   'Arab Winter',
#   'Counter-revolutionary',
#   'War in Iraq (2013–2017)',
#   'Libyan Crisis (2011–present)',
#   'Yemeni Crisis (2011–present)',
#   'Yemeni civil war (2014–present)',
#   'Timeline of terrorism in Egypt (2013–present)',
#   'Human rights',
#   'Internet',
#   'Islamism',
#   'Libya',
#   'North Africa',
#   'Prague Spring',
#   'Eastern Europe',
#   'United States Department of Homeland Security',
#   "Metcalfe's law",
#   'Political corruption',
#   'The Atlantic',
#   'Crowd psychology',
#   'Second World',
#   'Connectionism',
#   'National Endowment for Democracy',
#   'Democratization',
#   'Yemen',
#   'Syrian pound',
#   'Jan Palach',
#   'Foreign Policy',
#   'Subitizing',
#   'U.S. Customs and Border Protection',
#   'Participatory design',
#   'Arab states of the Persian Gulf',
#   'YouTube',
#   'Revolutions of 1989',
#   'Iraq War',
#   'Joseph Massad',
#   'Facebook',
#   'Egypt',
#   'Liberal democracy',
#   'Corn ethanol',
#   'Revolutions of 1848',
#   'Civil resistance',
#   'List of Facebook features',
#   'Bahrain',
#   'Great Recession',
#   'Collective intelligence',
#   'Marc Lynch',
#   'Death of Khaled Mohamed Saeed',
#   'Mohamed Bouazizi',
#   'Wael Ghonim',
#   'Syrian civil war',
#   'Al Jazeera',
#   'Turkish model',
#   'Zeynep Tufekci',
#   'Second Arab Spring',
#   'Algeria',
#   'Arabs',
#   'Cairo',
#   'Mosque',
#   'Tunisia',
#   'Hosni Mubarak',
#   'El Mahalla El Kubra',
#   'President of Egypt',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Laayoune',
#   'Sahrawis',
#   'Self-immolation',
#   'Gafsa',
#   'Jordan',
#   'Egypt',
#   'Tahrir Square',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Mohamed Bouazizi',
#   '2011 Egyptian revolution',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Libyan civil war (2011)',
#   '2011 Bahraini uprising',
#   '2011 Iraqi protests',
#   '2011 Djiboutian protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   '2011–2012 Saudi Arabian protests',
#   'Gdeim Izik protest camp',
#   'Kuwaiti protests (2011–2012)',
#   'Impact of the Arab Spring',
#   '2011–2012 Palestinian protests',
#   '2011 Western Saharan protests',
#   '2011–2012 Mauritanian protests',
#   'Syrian revolution',
#   'Revolutionary wave',
#   'Political freedom',
#   'Iran',
#   'Libya',
#   'Manama',
#   'North Africa',
#   'Shia Islam',
#   'Sudan',
#   'Time (magazine)',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Bahrain Defence Force',
#   'Tuareg people',
#   'Abdullah II of Jordan',
#   'Mohamed ElBaradei',
#   'Time Person of the Year',
#   'Ali Abdullah Saleh',
#   'State of emergency',
#   'Hamad bin Isa Al Khalifa',
#   'Omar al-Bashir',
#   'King of Bahrain',
#   'Media activism',
#   'World Press Photo',
#   'Juan E. Méndez',
#   'Nasser Al-Mohammed Al-Sabah',
#   'Nouri al-Maliki',
#   'Social media',
#   'Sirte',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Human rights in Bahrain',
#   'Peninsula Shield Force',
#   '2012 Egyptian presidential election',
#   'Nobel Peace Prize',
#   'Abdrabbuh Mansur Hadi',
#   'Tawakkol Karman',
#   'Pearl Roundabout',
#   '2011–2012 Saudi Arabian protests',
#   'Bab al-Azizia',
#   'National Transitional Council',
#   'Bahrain Independent Commission of Inquiry',
#   '2011 Nobel Peace Prize',
#   'Bloody Thursday (Bahrain)',
#   'Casualties of the 2011 Bahraini uprising and its aftermath',
#   'Samuel Aranda',
#   'Day of Rage (Bahrain)',
#   'March of loyalty to martyrs',
#   'Death of Abdulredha Buhmaid',
#   'Mali War',
#   'Tripoli, Libya',
#   'Muammar Gaddafi',
#   'Washington, D.C.',
#   'Libyan Desert',
#   'Benghazi',
#   'Gulf of Sidra',
#   'No-fly zone',
#   'Misrata',
#   'Tripolitania',
#   'Prime Minister of Egypt',
#   'Saif al-Islam Gaddafi',
#   'Sabha, Libya',
#   'Parliament of Egypt',
#   'The World (radio program)',
#   'Supreme Constitutional Court (Egypt)',
#   'United States',
#   'Habib el-Adly',
#   'History of Libya under Muammar Gaddafi',
#   'France',
#   'Sirte',
#   'Bani Walid',
#   'Nafusa Mountains',
#   'Egyptian Initiative for Personal Rights',
#   'Brega',
#   'Omar Suleiman (politician)',
#   'Tahrir Square',
#   'Ajdabiya',
#   'Emergency law in Egypt',
#   'Supreme Council of the Armed Forces',
#   'Battle of Misrata (2011)',
#   'National Transitional Council',
#   'Essam Sharaf',
#   '2011 military intervention in Libya',
#   'United Nations Security Council Resolution 1973',
#   'First Gulf of Sidra offensive',
#   'Battle of Brega–Ajdabiya road',
#   'Battle of Sabha',
#   'Mohamed Morsi',
#   'Battle of Tripoli (2011)',
#   'Battle of Sirte (2011)',
#   'Battle of Bani Walid',
#   'Killing of Muammar Gaddafi',
#   '2012–2013 Egyptian protests',
#   "2013 Egyptian coup d'état",
#   'Constitution of Egypt',
#   'Tahrir Institute for Middle East Policy',
#   'Damascus',
#   'Food',
#   'Political freedom',
#   'Lawyer',
#   'Inflation',
#   'Torture',
#   'Journalist',
#   'Aleppo',
#   'Solitary confinement',
#   'State of emergency',
#   'Daraa',
#   'Saudi Arabia',
#   'Bashar al-Assad',
#   'Zine El Abidine Ben Ali',
#   'Mohamed Ghannouchi',
#   'Democratic Constitutional Rally',
#   'President of Tunisia',
#   'Hama',
#   'Enforced disappearance',
#   'South Yemen',
#   'Deir ez-Zor',
#   'Sidi Bouzid',
#   'Habitability',
#   'Abu Kamal',
#   'Human rights defender',
#   'Federal National Council',
#   'Syria',
#   'Al-Hasakah',
#   'Open government',
#   'Arbitrary arrest and detention',
#   'Amnesty International',
#   'Freedom of speech',
#   'Mohamed Bouazizi',
#   '2014 Tunisian presidential election',
#   'Syrian civil war',
#   'Ennahda',
#   'Beji Caid Essebsi',
#   '2011 Tunisian Constituent Assembly election',
#   "Arab Socialist Ba'ath Party – Syria Region",
#   'Al-Hirak, Syria',
#   'Nidaa Tounes',
#   'Suheir Atassi',
#   'Al Islah (United Arab Emirates)',
#   'Activism',
#   '2014 Tunisian parliamentary election',
#   'Tunisian Constitution of 2014',
#   'Libyan Crisis (2011–present)',
#   'Ahmed Mansoor',
#   'Algeria',
#   'Al-Qaeda',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Persian Gulf',
#   'Sudan',
#   'The New Yorker',
#   'Aden',
#   'Riyadh',
#   'Arab League',
#   'Ali Abdullah Saleh',
#   'Gulf Cooperation Council',
#   'Human Development Index',
#   'Xinhua News Agency',
#   'Institution',
#   'Saudi Arabia',
#   "General People's Congress (Yemen)",
#   'Taiz',
#   'Robert D. Putnam',
#   'South Yemen',
#   'BBC News',
#   'Rentier state',
#   'Elections in Yemen',
#   'Arab states of the Persian Gulf',
#   'Societal collapse',
#   'Hashid',
#   'Human rights in Yemen',
#   'Syria',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Halim Barakat',
#   'Sanaa',
#   'Constitution of Yemen',
#   'Southern Movement',
#   'Abdrabbuh Mansur Hadi',
#   'Talk:Arab Spring',
#   'Tawakkol Karman',
#   'Al Jazeera',
#   '2012 Yemeni presidential election',
#   'Joel S. Migdal',
#   'World Bank',
#   'Yemeni civil war (2014–present)',
#   'Saudi-led intervention in the Yemeni civil war',
#   'Second Arab Spring',
#   'Free market',
#   'Gaza Strip',
#   'Muslim Brotherhood',
#   'Nicaragua',
#   'Sudan',
#   'Saddam Hussein',
#   'Tunisia',
#   'Tripoli, Libya',
#   'Think tank',
#   'Non-governmental organization',
#   'Social justice',
#   'The Economist',
#   'Hosni Mubarak',
#   'Antonio Gramsci',
#   'London School of Economics',
#   'United States Agency for International Development',
#   'Military dictatorship',
#   'Prime Minister of Iraq',
#   'Civil society',
#   'National Endowment for Democracy',
#   'Abdelaziz Bouteflika',
#   'Omar al-Bashir',
#   'Gene Sharp',
#   'Barack Obama',
#   'Otpor',
#   'International Republican Institute',
#   'Asef Bayat',
#   'Elias Khoury',
#   'Hillary Clinton',
#   'International Center for Transitional Justice',
#   'Frank G. Wisner',
#   'Omar Suleiman (politician)',
#   'April 6 Youth Movement',
#   'Muslim Brotherhood in Egypt',
#   'Wael Ghonim',
#   'Supreme Council of the Armed Forces',
#   'Ennahda',
#   'Khalifa Haftar',
#   'Yassin al-Haj Saleh',
#   'Mohamed Morsi',
#   'Saudi-led intervention in Bahrain',
#   'Truth and Dignity Commission (Tunisia)',
#   'Sudanese revolution',
#   '2019 Gaza economic protests',
#   "2019 Sudanese coup d'état",
#   'Khartoum massacre',
#   'Sudanese transition to democracy',
#   'Transitional Sovereignty Council',
#   'Algeria',
#   'Colonialism',
#   'Dictatorship',
#   'Hezbollah',
#   'Libya',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Tunisia',
#   'Autocracy',
#   'Condoleezza Rice',
#   'Yemen',
#   'Zaydism',
#   'Proxy war',
#   'Woodrow Wilson International Center for Scholars',
#   'Middle East and North Africa',
#   'State-building',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Islamic State',
#   'Rached Ghannouchi',
#   'H. A. Hellyer',
#   'Houthi movement',
#   'Bahrain',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Al-Islah (Yemen)',
#   'Libyan civil war (2011)',
#   'Muslim Brotherhood in Egypt',
#   'Syrian civil war',
#   '2011 Bahraini uprising',
#   'Egyptian Crisis (2011–2014)',
#   '2011 Iraqi protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   'Kuwaiti protests (2011–2012)',
#   "2013 Egyptian coup d'état",
#   'Iran–Saudi Arabia proxy conflict',
#   'Marina Ottaway'],
#  1126326407: ['Algeria',
#   'Arabic',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Arab world',
#   'Ali Abdullah Saleh',
#   'State of Palestine',
#   'Power vacuum',
#   'Saudi Arabia',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Rebellion',
#   'Insurgency',
#   'Southern Provinces',
#   'Literal translation',
#   'Economic stagnation',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Facebook',
#   'Egypt',
#   'Islamic State',
#   'Djibouti',
#   'Mauritania',
#   'Bahrain',
#   'Nonviolent resistance',
#   'Authoritarianism',
#   'Tunisian Revolution',
#   'Syrian civil war',
#   'Egyptian Crisis (2011–2014)',
#   'Ash-shab yurid isqat an-nizam',
#   'Iraqi insurgency (2011–2013)',
#   "2013 Egyptian coup d'état",
#   'Post-coup unrest in Egypt (2013–2014)',
#   'Arab Winter',
#   'Counter-revolutionary',
#   'War in Iraq (2013–2017)',
#   'Libyan Crisis (2011–present)',
#   'Yemeni Crisis (2011–present)',
#   'Yemeni civil war (2014–present)',
#   'Timeline of terrorism in Egypt (2013–present)',
#   'Human rights',
#   'Internet',
#   'Islamism',
#   'Libya',
#   'North Africa',
#   'Prague Spring',
#   'Eastern Europe',
#   'United States Department of Homeland Security',
#   "Metcalfe's law",
#   'Political corruption',
#   'The Atlantic',
#   'Crowd psychology',
#   'Second World',
#   'Connectionism',
#   'National Endowment for Democracy',
#   'Democratization',
#   'Yemen',
#   'Syrian pound',
#   'Jan Palach',
#   'Foreign Policy',
#   'Subitizing',
#   'U.S. Customs and Border Protection',
#   'Participatory design',
#   'Arab states of the Persian Gulf',
#   'YouTube',
#   'Revolutions of 1989',
#   'Iraq War',
#   'Joseph Massad',
#   'Facebook',
#   'Egypt',
#   'Liberal democracy',
#   'Corn ethanol',
#   'Revolutions of 1848',
#   'Civil resistance',
#   'List of Facebook features',
#   'Bahrain',
#   'Great Recession',
#   'Collective intelligence',
#   'Marc Lynch',
#   'Death of Khaled Mohamed Saeed',
#   'Mohamed Bouazizi',
#   'Wael Ghonim',
#   'Syrian civil war',
#   'Al Jazeera',
#   'Turkish model',
#   'Zeynep Tufekci',
#   'Second Arab Spring',
#   'Algeria',
#   'Arabs',
#   'Cairo',
#   'Mosque',
#   'Tunisia',
#   'Hosni Mubarak',
#   'El Mahalla El Kubra',
#   'President of Egypt',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Laayoune',
#   'Sahrawis',
#   'Self-immolation',
#   'Gafsa',
#   'Jordan',
#   'Egypt',
#   'Tahrir Square',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Mohamed Bouazizi',
#   '2011 Egyptian revolution',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Libyan civil war (2011)',
#   '2011 Bahraini uprising',
#   '2011 Iraqi protests',
#   '2011 Djiboutian protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   '2011–2012 Saudi Arabian protests',
#   'Gdeim Izik protest camp',
#   'Kuwaiti protests (2011–2012)',
#   'Impact of the Arab Spring',
#   '2011–2012 Palestinian protests',
#   '2011 Western Saharan protests',
#   '2011–2012 Mauritanian protests',
#   'Syrian revolution',
#   'Revolutionary wave',
#   'Political freedom',
#   'Iran',
#   'Libya',
#   'Manama',
#   'North Africa',
#   'Shia Islam',
#   'Sudan',
#   'Time (magazine)',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Bahrain Defence Force',
#   'Tuareg people',
#   'Abdullah II of Jordan',
#   'Mohamed ElBaradei',
#   'Time Person of the Year',
#   'Ali Abdullah Saleh',
#   'State of emergency',
#   'Hamad bin Isa Al Khalifa',
#   'Omar al-Bashir',
#   'King of Bahrain',
#   'Media activism',
#   'World Press Photo',
#   'Juan E. Méndez',
#   'Nasser Al-Mohammed Al-Sabah',
#   'Nouri al-Maliki',
#   'Social media',
#   'Sirte',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Human rights in Bahrain',
#   'Peninsula Shield Force',
#   '2012 Egyptian presidential election',
#   'Nobel Peace Prize',
#   'Abdrabbuh Mansur Hadi',
#   'Tawakkol Karman',
#   'Pearl Roundabout',
#   '2011–2012 Saudi Arabian protests',
#   'Bab al-Azizia',
#   'National Transitional Council',
#   'Bahrain Independent Commission of Inquiry',
#   '2011 Nobel Peace Prize',
#   'Bloody Thursday (Bahrain)',
#   'Casualties of the 2011 Bahraini uprising and its aftermath',
#   'Samuel Aranda',
#   'Day of Rage (Bahrain)',
#   'March of loyalty to martyrs',
#   'Death of Abdulredha Buhmaid',
#   'Mali War',
#   'Tripoli, Libya',
#   'Muammar Gaddafi',
#   'Washington, D.C.',
#   'Libyan Desert',
#   'Benghazi',
#   'Gulf of Sidra',
#   'No-fly zone',
#   'Misrata',
#   'Tripolitania',
#   'Prime Minister of Egypt',
#   'Saif al-Islam Gaddafi',
#   'Sabha, Libya',
#   'Parliament of Egypt',
#   'The World (radio program)',
#   'Supreme Constitutional Court (Egypt)',
#   'United States',
#   'Habib el-Adly',
#   'History of Libya under Muammar Gaddafi',
#   'France',
#   'Sirte',
#   'Bani Walid',
#   'Nafusa Mountains',
#   'Egyptian Initiative for Personal Rights',
#   'Brega',
#   'Omar Suleiman (politician)',
#   'Tahrir Square',
#   'Ajdabiya',
#   'Emergency law in Egypt',
#   'Supreme Council of the Armed Forces',
#   'Battle of Misrata (2011)',
#   'National Transitional Council',
#   'Essam Sharaf',
#   '2011 military intervention in Libya',
#   'United Nations Security Council Resolution 1973',
#   'First Gulf of Sidra offensive',
#   'Battle of Brega–Ajdabiya road',
#   'Battle of Sabha',
#   'Mohamed Morsi',
#   'Battle of Tripoli (2011)',
#   'Battle of Sirte (2011)',
#   'Battle of Bani Walid',
#   'Killing of Muammar Gaddafi',
#   '2012–2013 Egyptian protests',
#   "2013 Egyptian coup d'état",
#   'Constitution of Egypt',
#   'Tahrir Institute for Middle East Policy',
#   'Damascus',
#   'Food',
#   'Political freedom',
#   'Lawyer',
#   'Inflation',
#   'Torture',
#   'Journalist',
#   'Aleppo',
#   'Solitary confinement',
#   'State of emergency',
#   'Daraa',
#   'Saudi Arabia',
#   'Bashar al-Assad',
#   'Zine El Abidine Ben Ali',
#   'Mohamed Ghannouchi',
#   'Democratic Constitutional Rally',
#   'President of Tunisia',
#   'Hama',
#   'Enforced disappearance',
#   'South Yemen',
#   'Deir ez-Zor',
#   'Sidi Bouzid',
#   'Habitability',
#   'Abu Kamal',
#   'Human rights defender',
#   'Federal National Council',
#   'Syria',
#   'Al-Hasakah',
#   'Open government',
#   'Arbitrary arrest and detention',
#   'Amnesty International',
#   'Freedom of speech',
#   'Mohamed Bouazizi',
#   '2014 Tunisian presidential election',
#   'Syrian civil war',
#   'Ennahda',
#   'Beji Caid Essebsi',
#   '2011 Tunisian Constituent Assembly election',
#   "Arab Socialist Ba'ath Party – Syria Region",
#   'Al-Hirak, Syria',
#   'Nidaa Tounes',
#   'Suheir Atassi',
#   'Al Islah (United Arab Emirates)',
#   'Activism',
#   '2014 Tunisian parliamentary election',
#   'Tunisian Constitution of 2014',
#   'Libyan Crisis (2011–present)',
#   'Ahmed Mansoor',
#   'Algeria',
#   'Al-Qaeda',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Persian Gulf',
#   'Sudan',
#   'The New Yorker',
#   'Aden',
#   'Riyadh',
#   'Arab League',
#   'Ali Abdullah Saleh',
#   'Gulf Cooperation Council',
#   'Human Development Index',
#   'Xinhua News Agency',
#   'Institution',
#   'Saudi Arabia',
#   "General People's Congress (Yemen)",
#   'Taiz',
#   'Robert D. Putnam',
#   'South Yemen',
#   'BBC News',
#   'Rentier state',
#   'Elections in Yemen',
#   'Arab states of the Persian Gulf',
#   'Societal collapse',
#   'Hashid',
#   'Human rights in Yemen',
#   'Syria',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Halim Barakat',
#   'Sanaa',
#   'Constitution of Yemen',
#   'Southern Movement',
#   'Abdrabbuh Mansur Hadi',
#   'Talk:Arab Spring',
#   'Tawakkol Karman',
#   'Al Jazeera',
#   '2012 Yemeni presidential election',
#   'Joel S. Migdal',
#   'World Bank',
#   'Yemeni civil war (2014–present)',
#   'Saudi-led intervention in the Yemeni civil war',
#   'Second Arab Spring',
#   'Free market',
#   'Gaza Strip',
#   'Muslim Brotherhood',
#   'Nicaragua',
#   'Sudan',
#   'Saddam Hussein',
#   'Tunisia',
#   'Tripoli, Libya',
#   'Think tank',
#   'Non-governmental organization',
#   'Social justice',
#   'The Economist',
#   'Hosni Mubarak',
#   'Antonio Gramsci',
#   'London School of Economics',
#   'United States Agency for International Development',
#   'Military dictatorship',
#   'Prime Minister of Iraq',
#   'Civil society',
#   'National Endowment for Democracy',
#   'Abdelaziz Bouteflika',
#   'Omar al-Bashir',
#   'Gene Sharp',
#   'Barack Obama',
#   'Otpor',
#   'International Republican Institute',
#   'Asef Bayat',
#   'Elias Khoury',
#   'Hillary Clinton',
#   'International Center for Transitional Justice',
#   'Frank G. Wisner',
#   'Omar Suleiman (politician)',
#   'April 6 Youth Movement',
#   'Muslim Brotherhood in Egypt',
#   'Wael Ghonim',
#   'Supreme Council of the Armed Forces',
#   'Ennahda',
#   'Khalifa Haftar',
#   'Yassin al-Haj Saleh',
#   'Mohamed Morsi',
#   'Saudi-led intervention in Bahrain',
#   'Truth and Dignity Commission (Tunisia)',
#   'Sudanese revolution',
#   '2019 Gaza economic protests',
#   "2019 Sudanese coup d'état",
#   'Khartoum massacre',
#   'Sudanese transition to democracy',
#   'Transitional Sovereignty Council',
#   'Algeria',
#   'Colonialism',
#   'Dictatorship',
#   'Hezbollah',
#   'Libya',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Tunisia',
#   'Autocracy',
#   'Condoleezza Rice',
#   'Yemen',
#   'Zaydism',
#   'Proxy war',
#   'Woodrow Wilson International Center for Scholars',
#   'Middle East and North Africa',
#   'State-building',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Islamic State',
#   'Rached Ghannouchi',
#   'H. A. Hellyer',
#   'Houthi movement',
#   'Bahrain',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Al-Islah (Yemen)',
#   'Libyan civil war (2011)',
#   'Muslim Brotherhood in Egypt',
#   'Syrian civil war',
#   '2011 Bahraini uprising',
#   'Egyptian Crisis (2011–2014)',
#   '2011 Iraqi protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   'Kuwaiti protests (2011–2012)',
#   "2013 Egyptian coup d'état",
#   'Iran–Saudi Arabia proxy conflict',
#   'Marina Ottaway'],
#  1130279099: ['Algeria',
#   'Arabic',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Arab world',
#   'Ali Abdullah Saleh',
#   'State of Palestine',
#   'Power vacuum',
#   'Saudi Arabia',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Rebellion',
#   'Insurgency',
#   'Southern Provinces',
#   'Literal translation',
#   'Economic stagnation',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Facebook',
#   'Egypt',
#   'Islamic State',
#   'Djibouti',
#   'Mauritania',
#   'Bahrain',
#   'Nonviolent resistance',
#   'Authoritarianism',
#   'Tunisian Revolution',
#   'Syrian civil war',
#   'Egyptian Crisis (2011–2014)',
#   'Ash-shab yurid isqat an-nizam',
#   'Iraqi insurgency (2011–2013)',
#   "2013 Egyptian coup d'état",
#   'Post-coup unrest in Egypt (2013–2014)',
#   'Arab Winter',
#   'Counter-revolutionary',
#   'War in Iraq (2013–2017)',
#   'Libyan Crisis (2011–present)',
#   'Yemeni Crisis (2011–present)',
#   'Yemeni civil war (2014–present)',
#   'Timeline of terrorism in Egypt (2013–present)',
#   'Human rights',
#   'Internet',
#   'Islamism',
#   'Libya',
#   'North Africa',
#   'Prague Spring',
#   'Eastern Europe',
#   'United States Department of Homeland Security',
#   "Metcalfe's law",
#   'Political corruption',
#   'The Atlantic',
#   'Crowd psychology',
#   'Second World',
#   'Connectionism',
#   'National Endowment for Democracy',
#   'Democratization',
#   'Yemen',
#   'Syrian pound',
#   'Jan Palach',
#   'Foreign Policy',
#   'Subitizing',
#   'U.S. Customs and Border Protection',
#   'Participatory design',
#   'Arab states of the Persian Gulf',
#   'YouTube',
#   'Revolutions of 1989',
#   'Iraq War',
#   'Joseph Massad',
#   'Facebook',
#   'Egypt',
#   'Liberal democracy',
#   'Corn ethanol',
#   'Revolutions of 1848',
#   'Civil resistance',
#   'List of Facebook features',
#   'Bahrain',
#   'Great Recession',
#   'Collective intelligence',
#   'Marc Lynch',
#   'Death of Khaled Mohamed Saeed',
#   'Mohamed Bouazizi',
#   'Wael Ghonim',
#   'Syrian civil war',
#   'Al Jazeera',
#   'Turkish model',
#   'Zeynep Tufekci',
#   'Second Arab Spring',
#   'Algeria',
#   'Arabs',
#   'Cairo',
#   'Mosque',
#   'Tunisia',
#   'Hosni Mubarak',
#   'El Mahalla El Kubra',
#   'President of Egypt',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Laayoune',
#   'Sahrawis',
#   'Self-immolation',
#   'Gafsa',
#   'Jordan',
#   'Egypt',
#   'Tahrir Square',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Mohamed Bouazizi',
#   '2011 Egyptian revolution',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Libyan civil war (2011)',
#   '2011 Bahraini uprising',
#   '2011 Iraqi protests',
#   '2011 Djiboutian protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   '2011–2012 Saudi Arabian protests',
#   'Gdeim Izik protest camp',
#   'Kuwaiti protests (2011–2012)',
#   'Impact of the Arab Spring',
#   '2011–2012 Palestinian protests',
#   '2011 Western Saharan protests',
#   '2011–2012 Mauritanian protests',
#   'Syrian revolution',
#   'Revolutionary wave',
#   'Political freedom',
#   'Iran',
#   'Libya',
#   'Manama',
#   'North Africa',
#   'Shia Islam',
#   'Sudan',
#   'Time (magazine)',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Bahrain Defence Force',
#   'Tuareg people',
#   'Abdullah II of Jordan',
#   'Mohamed ElBaradei',
#   'Time Person of the Year',
#   'Ali Abdullah Saleh',
#   'State of emergency',
#   'Hamad bin Isa Al Khalifa',
#   'Omar al-Bashir',
#   'King of Bahrain',
#   'Media activism',
#   'World Press Photo',
#   'Juan E. Méndez',
#   'Nasser Al-Mohammed Al-Sabah',
#   'Nouri al-Maliki',
#   'Social media',
#   'Sirte',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Human rights in Bahrain',
#   'Peninsula Shield Force',
#   '2012 Egyptian presidential election',
#   'Nobel Peace Prize',
#   'Abdrabbuh Mansur Hadi',
#   'Tawakkol Karman',
#   'Pearl Roundabout',
#   '2011–2012 Saudi Arabian protests',
#   'Bab al-Azizia',
#   'National Transitional Council',
#   'Bahrain Independent Commission of Inquiry',
#   '2011 Nobel Peace Prize',
#   'Bloody Thursday (Bahrain)',
#   'Casualties of the 2011 Bahraini uprising and its aftermath',
#   'Samuel Aranda',
#   'Day of Rage (Bahrain)',
#   'March of loyalty to martyrs',
#   'Death of Abdulredha Buhmaid',
#   'Mali War',
#   'Tripoli, Libya',
#   'Muammar Gaddafi',
#   'Washington, D.C.',
#   'Libyan Desert',
#   'Benghazi',
#   'Gulf of Sidra',
#   'No-fly zone',
#   'Misrata',
#   'Tripolitania',
#   'Prime Minister of Egypt',
#   'Saif al-Islam Gaddafi',
#   'Sabha, Libya',
#   'Parliament of Egypt',
#   'The World (radio program)',
#   'Supreme Constitutional Court (Egypt)',
#   'United States',
#   'Habib el-Adly',
#   'History of Libya under Muammar Gaddafi',
#   'France',
#   'Sirte',
#   'Bani Walid',
#   'Nafusa Mountains',
#   'Egyptian Initiative for Personal Rights',
#   'Brega',
#   'Omar Suleiman (politician)',
#   'Tahrir Square',
#   'Ajdabiya',
#   'Emergency law in Egypt',
#   'Supreme Council of the Armed Forces',
#   'Battle of Misrata (2011)',
#   'National Transitional Council',
#   'Essam Sharaf',
#   '2011 military intervention in Libya',
#   'United Nations Security Council Resolution 1973',
#   'First Gulf of Sidra offensive',
#   'Battle of Brega–Ajdabiya road',
#   'Battle of Sabha',
#   'Mohamed Morsi',
#   'Battle of Tripoli (2011)',
#   'Battle of Sirte (2011)',
#   'Battle of Bani Walid',
#   'Killing of Muammar Gaddafi',
#   '2012–2013 Egyptian protests',
#   "2013 Egyptian coup d'état",
#   'Constitution of Egypt',
#   'Tahrir Institute for Middle East Policy',
#   'Damascus',
#   'Food',
#   'Political freedom',
#   'Lawyer',
#   'Inflation',
#   'Torture',
#   'Journalist',
#   'Aleppo',
#   'Solitary confinement',
#   'State of emergency',
#   'Daraa',
#   'Saudi Arabia',
#   'Bashar al-Assad',
#   'Zine El Abidine Ben Ali',
#   'Mohamed Ghannouchi',
#   'Democratic Constitutional Rally',
#   'President of Tunisia',
#   'Hama',
#   'Enforced disappearance',
#   'South Yemen',
#   'Deir ez-Zor',
#   'Sidi Bouzid',
#   'Habitability',
#   'Abu Kamal',
#   'Human rights defender',
#   'Federal National Council',
#   'Syria',
#   'Al-Hasakah',
#   'Open government',
#   'Arbitrary arrest and detention',
#   'Amnesty International',
#   'Freedom of speech',
#   'Mohamed Bouazizi',
#   '2014 Tunisian presidential election',
#   'Syrian civil war',
#   'Ennahda',
#   'Beji Caid Essebsi',
#   '2011 Tunisian Constituent Assembly election',
#   "Arab Socialist Ba'ath Party – Syria Region",
#   'Al-Hirak, Syria',
#   'Nidaa Tounes',
#   'Suheir Atassi',
#   'Al Islah (United Arab Emirates)',
#   'Activism',
#   '2014 Tunisian parliamentary election',
#   'Tunisian Constitution of 2014',
#   'Libyan Crisis (2011–present)',
#   'Ahmed Mansoor',
#   'Algeria',
#   'Al-Qaeda',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Persian Gulf',
#   'Sudan',
#   'The New Yorker',
#   'Aden',
#   'Riyadh',
#   'Arab League',
#   'Ali Abdullah Saleh',
#   'Gulf Cooperation Council',
#   'Human Development Index',
#   'Xinhua News Agency',
#   'Institution',
#   'Saudi Arabia',
#   "General People's Congress (Yemen)",
#   'Taiz',
#   'Robert D. Putnam',
#   'South Yemen',
#   'BBC News',
#   'Rentier state',
#   'Elections in Yemen',
#   'Arab states of the Persian Gulf',
#   'Societal collapse',
#   'Hashid',
#   'Human rights in Yemen',
#   'Syria',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Halim Barakat',
#   'Sanaa',
#   'Constitution of Yemen',
#   'Southern Movement',
#   'Abdrabbuh Mansur Hadi',
#   'Talk:Arab Spring',
#   'Tawakkol Karman',
#   'Al Jazeera',
#   '2012 Yemeni presidential election',
#   'Joel S. Migdal',
#   'World Bank',
#   'Yemeni civil war (2014–present)',
#   'Saudi-led intervention in the Yemeni civil war',
#   'Second Arab Spring',
#   'Free market',
#   'Gaza Strip',
#   'Muslim Brotherhood',
#   'Nicaragua',
#   'Sudan',
#   'Saddam Hussein',
#   'Tunisia',
#   'Tripoli, Libya',
#   'Think tank',
#   'Non-governmental organization',
#   'Social justice',
#   'The Economist',
#   'Hosni Mubarak',
#   'Antonio Gramsci',
#   'London School of Economics',
#   'United States Agency for International Development',
#   'Military dictatorship',
#   'Prime Minister of Iraq',
#   'Civil society',
#   'National Endowment for Democracy',
#   'Abdelaziz Bouteflika',
#   'Omar al-Bashir',
#   'Gene Sharp',
#   'Barack Obama',
#   'Otpor',
#   'International Republican Institute',
#   'Asef Bayat',
#   'Elias Khoury',
#   'Hillary Clinton',
#   'International Center for Transitional Justice',
#   'Frank G. Wisner',
#   'Omar Suleiman (politician)',
#   'April 6 Youth Movement',
#   'Muslim Brotherhood in Egypt',
#   'Wael Ghonim',
#   'Supreme Council of the Armed Forces',
#   'Ennahda',
#   'Khalifa Haftar',
#   'Yassin al-Haj Saleh',
#   'Mohamed Morsi',
#   'Saudi-led intervention in Bahrain',
#   'Truth and Dignity Commission (Tunisia)',
#   'Sudanese revolution',
#   '2019 Gaza economic protests',
#   "2019 Sudanese coup d'état",
#   'Khartoum massacre',
#   'Sudanese transition to democracy',
#   'Transitional Sovereignty Council',
#   'Algeria',
#   'Colonialism',
#   'Dictatorship',
#   'Hezbollah',
#   'Libya',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Tunisia',
#   'Autocracy',
#   'Condoleezza Rice',
#   'Yemen',
#   'Zaydism',
#   'Proxy war',
#   'Woodrow Wilson International Center for Scholars',
#   'Middle East and North Africa',
#   'State-building',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Islamic State',
#   'Rached Ghannouchi',
#   'H. A. Hellyer',
# ...
#   'Mohamed ElBaradei',
#   'Time Person of the Year',
#   'Ali Abdullah Saleh',
#   'State of emergency',
#   'Hamad bin Isa Al Khalifa',
#   'Omar al-Bashir',
#   'King of Bahrain',
#   'Media activism',
#   'World Press Photo',
#   'Juan E. Méndez',
#   'Nasser Al-Mohammed Al-Sabah',
#   'Nouri al-Maliki',
#   'Jamal Khashoggi',
#   'Social media',
#   'Sirte',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Human rights in Bahrain',
#   'Peninsula Shield Force',
#   '2012 Egyptian presidential election',
#   'Nobel Peace Prize',
#   'Abdrabbuh Mansur Hadi',
#   'Tawakkol Karman',
#   'Pearl Roundabout',
#   '2011–2012 Saudi Arabian protests',
#   'Bab al-Azizia',
#   'National Transitional Council',
#   'Bahrain Independent Commission of Inquiry',
#   '2011 Nobel Peace Prize',
#   'Bloody Thursday (Bahrain)',
#   'Casualties of the 2011 Bahraini uprising and its aftermath',
#   'Samuel Aranda',
#   'Day of Rage (Bahrain)',
#   'March of loyalty to martyrs',
#   'Death of Abdulredha Buhmaid',
#   'Mali War',
#   'Tripoli, Libya',
#   'Muammar Gaddafi',
#   'Washington, D.C.',
#   'Libyan Desert',
#   'Benghazi',
#   'Gulf of Sidra',
#   'No-fly zone',
#   'Misrata',
#   'Tripolitania',
#   'Prime Minister of Egypt',
#   'Saif al-Islam Gaddafi',
#   'Sabha, Libya',
#   'Parliament of Egypt',
#   'The World (radio program)',
#   'Supreme Constitutional Court (Egypt)',
#   'United States',
#   'Habib el-Adly',
#   'History of Libya under Muammar Gaddafi',
#   'France',
#   'Sirte',
#   'Bani Walid',
#   'Nafusa Mountains',
#   'Egyptian Initiative for Personal Rights',
#   'Brega',
#   'Omar Suleiman (politician)',
#   'Tahrir Square',
#   'Ajdabiya',
#   'Emergency law in Egypt',
#   'Supreme Council of the Armed Forces',
#   'Battle of Misrata (2011)',
#   'National Transitional Council',
#   'Essam Sharaf',
#   '2011 military intervention in Libya',
#   'United Nations Security Council Resolution 1973',
#   'First Gulf of Sidra offensive',
#   'Battle of Brega–Ajdabiya road',
#   'Battle of Sabha',
#   'Mohamed Morsi',
#   'Battle of Tripoli (2011)',
#   'Battle of Sirte (2011)',
#   'Battle of Bani Walid',
#   'Killing of Muammar Gaddafi',
#   '2012–2013 Egyptian protests',
#   "2013 Egyptian coup d'état",
#   'Constitution of Egypt',
#   'Tahrir Institute for Middle East Policy',
#   'Damascus',
#   'Food',
#   'Political freedom',
#   'Lawyer',
#   'Inflation',
#   'Torture',
#   'Journalist',
#   'Aleppo',
#   'Solitary confinement',
#   'State of emergency',
#   'Daraa',
#   'Saudi Arabia',
#   'Bashar al-Assad',
#   'Zine El Abidine Ben Ali',
#   'Mohamed Ghannouchi',
#   'Democratic Constitutional Rally',
#   'President of Tunisia',
#   'Hama',
#   'Enforced disappearance',
#   'South Yemen',
#   'Deir ez-Zor',
#   'Sidi Bouzid',
#   'Habitability',
#   'Abu Kamal',
#   'Human rights defender',
#   'Federal National Council',
#   'Syria',
#   'Al-Hasakah',
#   'Open government',
#   'Arbitrary arrest and detention',
#   'Amnesty International',
#   'Freedom of speech',
#   'Mohamed Bouazizi',
#   '2014 Tunisian presidential election',
#   'Syrian civil war',
#   'Ennahda',
#   'Beji Caid Essebsi',
#   '2011 Tunisian Constituent Assembly election',
#   "Arab Socialist Ba'ath Party – Syria Region",
#   'Al-Hirak, Syria',
#   'Nidaa Tounes',
#   'Suheir Atassi',
#   'Al Islah (United Arab Emirates)',
#   'Activism',
#   '2014 Tunisian parliamentary election',
#   'Tunisian Constitution of 2014',
#   'Libyan Crisis (2011–present)',
#   'Ahmed Mansoor',
#   'Algeria',
#   'Al-Qaeda',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Persian Gulf',
#   'Sudan',
#   'The New Yorker',
#   'Aden',
#   'Riyadh',
#   'Arab League',
#   'Ali Abdullah Saleh',
#   'Gulf Cooperation Council',
#   'Human Development Index',
#   'Xinhua News Agency',
#   'Institution',
#   'Saudi Arabia',
#   "General People's Congress (Yemen)",
#   'Taiz',
#   'Robert D. Putnam',
#   'South Yemen',
#   'BBC News',
#   'Rentier state',
#   'Elections in Yemen',
#   'Arab states of the Persian Gulf',
#   'Societal collapse',
#   'Hashid',
#   'Human rights in Yemen',
#   'Syria',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Halim Barakat',
#   'Sanaa',
#   'Constitution of Yemen',
#   'Southern Movement',
#   'Abdrabbuh Mansur Hadi',
#   'Talk:Arab Spring',
#   'Tawakkol Karman',
#   'Al Jazeera',
#   '2012 Yemeni presidential election',
#   'Joel S. Migdal',
#   'World Bank',
#   'Yemeni civil war (2014–present)',
#   'Saudi-led intervention in the Yemeni civil war',
#   'Second Arab Spring',
#   'Free market',
#   'Gaza Strip',
#   'Muslim Brotherhood',
#   'Nicaragua',
#   'Sudan',
#   'Saddam Hussein',
#   'Tunisia',
#   'Tripoli, Libya',
#   'Think tank',
#   'Non-governmental organization',
#   'Social justice',
#   'The Economist',
#   'Hosni Mubarak',
#   'Antonio Gramsci',
#   'London School of Economics',
#   'United States Agency for International Development',
#   'Military dictatorship',
#   'Prime Minister of Iraq',
#   'Civil society',
#   'National Endowment for Democracy',
#   'Abdelaziz Bouteflika',
#   'Omar al-Bashir',
#   'Gene Sharp',
#   'Barack Obama',
#   'Otpor',
#   'International Republican Institute',
#   'Asef Bayat',
#   'Elias Khoury',
#   'Hillary Clinton',
#   'International Center for Transitional Justice',
#   'Frank G. Wisner',
#   'Omar Suleiman (politician)',
#   'April 6 Youth Movement',
#   'Muslim Brotherhood in Egypt',
#   'Wael Ghonim',
#   'Supreme Council of the Armed Forces',
#   'Ennahda',
#   'Khalifa Haftar',
#   'Yassin al-Haj Saleh',
#   'Mohamed Morsi',
#   'Saudi-led intervention in Bahrain',
#   'Truth and Dignity Commission (Tunisia)',
#   'Sudanese revolution',
#   '2019 Gaza economic protests',
#   "2019 Sudanese coup d'état",
#   'Khartoum massacre',
#   'Sudanese transition to democracy',
#   'Transitional Sovereignty Council',
#   'Algeria',
#   'Colonialism',
#   'Dictatorship',
#   'Hezbollah',
#   'Libya',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Tunisia',
#   'Autocracy',
#   'Condoleezza Rice',
#   'Yemen',
#   'Zaydism',
#   'Proxy war',
#   'Woodrow Wilson International Center for Scholars',
#   'Middle East and North Africa',
#   'State-building',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Islamic State',
#   'Rached Ghannouchi',
#   'H. A. Hellyer',
#   'Houthi movement',
#   'Bahrain',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Al-Islah (Yemen)',
#   'Libyan civil war (2011)',
#   'Muslim Brotherhood in Egypt',
#   'Syrian civil war',
#   '2011 Bahraini uprising',
#   'Egyptian Crisis (2011–2014)',
#   '2011 Iraqi protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   'Kuwaiti protests (2011–2012)',
#   "2013 Egyptian coup d'état",
#   'Iran–Saudi Arabia proxy conflict',
#   'Marina Ottaway'],
#  1130729700: ['Algeria',
#   'Arabic',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Arab world',
#   'Ali Abdullah Saleh',
#   'State of Palestine',
#   'Power vacuum',
#   'Saudi Arabia',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Rebellion',
#   'Insurgency',
#   'Southern Provinces',
#   'Literal translation',
#   'Economic stagnation',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Islamic State',
#   'Djibouti',
#   'Mauritania',
#   'Bahrain',
#   'Nonviolent resistance',
#   'Authoritarianism',
#   'Tunisian Revolution',
#   'Syrian civil war',
#   'Egyptian Crisis (2011–2014)',
#   'Ash-shab yurid isqat an-nizam',
#   'Iraqi insurgency (2011–2013)',
#   "2013 Egyptian coup d'état",
#   'Post-coup unrest in Egypt (2013–2014)',
#   'Arab Winter',
#   'Counter-revolutionary',
#   'War in Iraq (2013–2017)',
#   'Libyan Crisis (2011–present)',
#   'Yemeni Crisis (2011–present)',
#   'Yemeni civil war (2014–present)',
#   'Timeline of terrorism in Egypt (2013–present)',
#   'Second Arab Spring',
#   'Cairo',
#   'Human rights',
#   'Internet',
#   'Islamism',
#   'Libya',
#   'North Africa',
#   'Prague Spring',
#   'Eastern Europe',
#   'United States Department of Homeland Security',
#   "Metcalfe's law",
#   'Political corruption',
#   'The Atlantic',
#   'Crowd psychology',
#   'Second World',
#   'Connectionism',
#   'National Endowment for Democracy',
#   'Democratization',
#   'Yemen',
#   'Syrian pound',
#   'Jan Palach',
#   'Foreign Policy',
#   'Subitizing',
#   'U.S. Customs and Border Protection',
#   'Participatory design',
#   'Arab states of the Persian Gulf',
#   'YouTube',
#   'Revolutions of 1989',
#   'Iraq War',
#   'Joseph Massad',
#   'Facebook',
#   'Egypt',
#   'Liberal democracy',
#   'Corn ethanol',
#   'Revolutions of 1848',
#   'Civil resistance',
#   'List of Facebook features',
#   'Bahrain',
#   'Great Recession',
#   'Collective intelligence',
#   'Marc Lynch',
#   'Death of Khaled Mohamed Saeed',
#   'Mohamed Bouazizi',
#   'Wael Ghonim',
#   'Syrian civil war',
#   'Al Jazeera',
#   'Turkish model',
#   'Zeynep Tufekci',
#   'Algeria',
#   'Arabs',
#   'Cairo',
#   'Libya',
#   'Mosque',
#   'Tunisia',
#   'Hosni Mubarak',
#   'El Mahalla El Kubra',
#   'President of Egypt',
#   'Yemen',
#   'Zine El Abidine Ben Ali',
#   'Laayoune',
#   'Sahrawis',
#   'Self-immolation',
#   'Gafsa',
#   'Jordan',
#   'Egypt',
#   'Tahrir Square',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Mohamed Bouazizi',
#   '2011 Egyptian revolution',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Libyan civil war (2011)',
#   '2011 Bahraini uprising',
#   '2011 Iraqi protests',
#   '2011 Djiboutian protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   '2011–2012 Saudi Arabian protests',
#   'Gdeim Izik protest camp',
#   'Kuwaiti protests (2011–2012)',
#   'Impact of the Arab Spring',
#   '2011–2012 Palestinian protests',
#   '2011 Western Saharan protests',
#   '2011–2012 Mauritanian protests',
#   'Syrian revolution',
#   'Revolutionary wave',
#   'Political freedom',
#   'Iran',
#   'Manama',
#   'North Africa',
#   'Shia Islam',
#   'Sudan',
#   'Time (magazine)',
#   'Hosni Mubarak',
#   'Muammar Gaddafi',
#   'Bahrain Defence Force',
#   'Tuareg people',
#   'Abdullah II of Jordan',
#   'Mohamed ElBaradei',
#   'Time Person of the Year',
#   'Ali Abdullah Saleh',
#   'State of emergency',
#   'Hamad bin Isa Al Khalifa',
#   'Omar al-Bashir',
#   'King of Bahrain',
#   'Media activism',
#   'World Press Photo',
#   'Juan E. Méndez',
#   'Nasser Al-Mohammed Al-Sabah',
#   'Nouri al-Maliki',
#   'Jamal Khashoggi',
#   'Social media',
#   'Sirte',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Human rights in Bahrain',
#   'Peninsula Shield Force',
#   '2012 Egyptian presidential election',
#   'Nobel Peace Prize',
#   'Abdrabbuh Mansur Hadi',
#   'Tawakkol Karman',
#   'Pearl Roundabout',
#   '2011–2012 Saudi Arabian protests',
#   'Bab al-Azizia',
#   'National Transitional Council',
#   'Bahrain Independent Commission of Inquiry',
#   '2011 Nobel Peace Prize',
#   'Bloody Thursday (Bahrain)',
#   'Casualties of the 2011 Bahraini uprising and its aftermath',
#   'Samuel Aranda',
#   'Day of Rage (Bahrain)',
#   'March of loyalty to martyrs',
#   'Death of Abdulredha Buhmaid',
#   'Mali War',
#   'Tripoli, Libya',
#   'Muammar Gaddafi',
#   'Washington, D.C.',
#   'Libyan Desert',
#   'Benghazi',
#   'Gulf of Sidra',
#   'No-fly zone',
#   'Misrata',
#   'Tripolitania',
#   'Prime Minister of Egypt',
#   'Saif al-Islam Gaddafi',
#   'Sabha, Libya',
#   'Parliament of Egypt',
#   'The World (radio program)',
#   'Supreme Constitutional Court (Egypt)',
#   'United States',
#   'Habib el-Adly',
#   'History of Libya under Muammar Gaddafi',
#   'France',
#   'Sirte',
#   'Bani Walid',
#   'Nafusa Mountains',
#   'Egyptian Initiative for Personal Rights',
#   'Brega',
#   'Omar Suleiman (politician)',
#   'Tahrir Square',
#   'Ajdabiya',
#   'Emergency law in Egypt',
#   'Supreme Council of the Armed Forces',
#   'Battle of Misrata (2011)',
#   'National Transitional Council',
#   'Essam Sharaf',
#   '2011 military intervention in Libya',
#   'United Nations Security Council Resolution 1973',
#   'First Gulf of Sidra offensive',
#   'Battle of Brega–Ajdabiya road',
#   'Battle of Sabha',
#   'Mohamed Morsi',
#   'Battle of Tripoli (2011)',
#   'Battle of Sirte (2011)',
#   'Battle of Bani Walid',
#   'Killing of Muammar Gaddafi',
#   '2012–2013 Egyptian protests',
#   "2013 Egyptian coup d'état",
#   'Constitution of Egypt',
#   'Tahrir Institute for Middle East Policy',
#   'Damascus',
#   'Food',
#   'Political freedom',
#   'Lawyer',
#   'Inflation',
#   'Torture',
#   'Journalist',
#   'Aleppo',
#   'Solitary confinement',
#   'State of emergency',
#   'Daraa',
#   'Saudi Arabia',
#   'Bashar al-Assad',
#   'Zine El Abidine Ben Ali',
#   'Mohamed Ghannouchi',
#   'Democratic Constitutional Rally',
#   'President of Tunisia',
#   'Hama',
#   'Enforced disappearance',
#   'South Yemen',
#   'Deir ez-Zor',
#   'Sidi Bouzid',
#   'Habitability',
#   'Abu Kamal',
#   'Human rights defender',
#   'Federal National Council',
#   'Syria',
#   'Al-Hasakah',
#   'Open government',
#   'Arbitrary arrest and detention',
#   'Amnesty International',
#   'Freedom of speech',
#   'Mohamed Bouazizi',
#   '2014 Tunisian presidential election',
#   'Syrian civil war',
#   'Ennahda',
#   'Beji Caid Essebsi',
#   '2011 Tunisian Constituent Assembly election',
#   "Arab Socialist Ba'ath Party – Syria Region",
#   'Al-Hirak, Syria',
#   'Nidaa Tounes',
#   'Suheir Atassi',
#   'Al Islah (United Arab Emirates)',
#   'Activism',
#   '2014 Tunisian parliamentary election',
#   'Tunisian Constitution of 2014',
#   'Libyan Crisis (2011–present)',
#   'Ahmed Mansoor',
#   'Algeria',
#   'Al-Qaeda',
#   'Libya',
#   'Lebanon',
#   'Morocco',
#   'Oman',
#   'Persian Gulf',
#   'Sudan',
#   'The New Yorker',
#   'Aden',
#   'Riyadh',
#   'Arab League',
#   'Ali Abdullah Saleh',
#   'Gulf Cooperation Council',
#   'Human Development Index',
#   'Xinhua News Agency',
#   'Institution',
#   'Saudi Arabia',
#   "General People's Congress (Yemen)",
#   'Taiz',
#   'Robert D. Putnam',
#   'South Yemen',
#   'BBC News',
#   'Rentier state',
#   'Elections in Yemen',
#   'Arab states of the Persian Gulf',
#   'Societal collapse',
#   'Hashid',
#   'Human rights in Yemen',
#   'Syria',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Halim Barakat',
#   'Sanaa',
#   'Constitution of Yemen',
#   'Southern Movement',
#   'Abdrabbuh Mansur Hadi',
#   'Talk:Arab Spring',
#   'Tawakkol Karman',
#   'Al Jazeera',
#   '2012 Yemeni presidential election',
#   'Joel S. Migdal',
#   'World Bank',
#   'Yemeni civil war (2014–present)',
#   'Saudi-led intervention in the Yemeni civil war',
#   'Second Arab Spring',
#   'Free market',
#   'Gaza Strip',
#   'Muslim Brotherhood',
#   'Nicaragua',
#   'Sudan',
#   'Saddam Hussein',
#   'Tunisia',
#   'Tripoli, Libya',
#   'Think tank',
#   'Non-governmental organization',
#   'Social justice',
#   'The Economist',
#   'Hosni Mubarak',
#   'Antonio Gramsci',
#   'London School of Economics',
#   'United States Agency for International Development',
#   'Military dictatorship',
#   'Prime Minister of Iraq',
#   'Civil society',
#   'National Endowment for Democracy',
#   'Abdelaziz Bouteflika',
#   'Omar al-Bashir',
#   'Gene Sharp',
#   'Barack Obama',
#   'Otpor',
#   'International Republican Institute',
#   'Asef Bayat',
#   'Elias Khoury',
#   'Hillary Clinton',
#   'International Center for Transitional Justice',
#   'Frank G. Wisner',
#   'Omar Suleiman (politician)',
#   'April 6 Youth Movement',
#   'Muslim Brotherhood in Egypt',
#   'Wael Ghonim',
#   'Supreme Council of the Armed Forces',
#   'Ennahda',
#   'Khalifa Haftar',
#   'Yassin al-Haj Saleh',
#   'Mohamed Morsi',
#   'Saudi-led intervention in Bahrain',
#   'Truth and Dignity Commission (Tunisia)',
#   'Sudanese revolution',
#   '2019 Gaza economic protests',
#   "2019 Sudanese coup d'état",
#   'Khartoum massacre',
#   'Sudanese transition to democracy',
#   'Transitional Sovereignty Council',
#   'Algeria',
#   'Colonialism',
#   'Dictatorship',
#   'Hezbollah',
#   'Libya',
#   'Morocco',
#   'Oman',
#   'Sudan',
#   'Tunisia',
#   'Autocracy',
#   'Condoleezza Rice',
#   'Yemen',
#   'Zaydism',
#   'Proxy war',
#   'Woodrow Wilson International Center for Scholars',
#   'Middle East and North Africa',
#   'State-building',
#   'Syria',
#   'Kuwait',
#   'Iraq',
#   'Jordan',
#   'Egypt',
#   'Islamic State',
#   'Rached Ghannouchi',
#   'H. A. Hellyer',
#   'Houthi movement',
#   'Bahrain',
#   'Tunisian Revolution',
#   '2010–2012 Algerian protests',
#   'Yemeni Revolution',
#   '2011–2012 Jordanian protests',
#   'Al-Islah (Yemen)',
#   'Libyan civil war (2011)',
#   'Muslim Brotherhood in Egypt',
#   'Syrian civil war',
#   '2011 Bahraini uprising',
#   'Egyptian Crisis (2011–2014)',
#   '2011 Iraqi protests',
#   '2011–2012 Moroccan protests',
#   '2011–2013 Sudanese protests',
#   '2011 Omani protests',
#   'Kuwaiti protests (2011–2012)',
#   "2013 Egyptian coup d'état",
#   'Iran–Saudi Arabia proxy conflict',
#   'Marina Ottaway']}

# %%
df2.loc[df2['revid'] == 1124986313] #2021-04-06 20:17:35+00:00
# df2.loc[df2['revid'] == 605463097] #2014-04-23 14:57:13+00:00
# 605463097
# Out:
#            revid                      time
# 9802  1124986313 2022-12-01 16:13:46+00:00
